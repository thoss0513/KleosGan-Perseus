# %% [markdown]
# # Training a Simple GAN Model for Sentence Embeddings

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms
from torch.utils.tensorboard import SummaryWriter  # to print to tensorboard
import pandas as pd
import ast
import numpy as np
from numpy import expand_dims
from numpy import zeros
from numpy import ones
from numpy import asarray
from numpy.random import randn
from numpy.random import randint
from keras.optimizers import Adam
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import Conv1D
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Dropout
from keras.layers import Lambda
from keras.layers import Activation
from matplotlib import pyplot as plt
from keras import backend
from keras.models import Sequential
from sklearn.model_selection import train_test_split


MAX_LENGTH = 768


class Discriminator(nn.Module):
    def __init__(self, in_features):
        super().__init__()
        self.disc = nn.Sequential(
            nn.Linear(in_features, 128),
            nn.LeakyReLU(0.01),
            nn.Linear(128, 1),
            nn.Sigmoid(),
        )

    def forward(self, x):
        return self.disc(x)

class Generator(nn.Module):
    def __init__(self, z_dim, emb_dim):
        super().__init__()
        self.gen = nn.Sequential(
            nn.Linear(z_dim, 256),
            nn.LeakyReLU(0.01),
            nn.Linear(256, emb_dim),
            nn.Tanh(),  # Assuming you want to normalize the outputs
        )

    def forward(self, x):
        return self.gen(x)


class CustomDataset(Dataset):
    def __init__(self, embeddings):
        self.embeddings = embeddings

    def __len__(self):
        return len(self.embeddings)

    def __getitem__(self, idx):
        return self.embeddings[idx]



# Hyperparameters etc.
device = "cuda" if torch.cuda.is_available() else "cpu"
lr = 3e-4
z_dim = 64
embed_dim = MAX_LENGTH  # 784
batch_size = 32
num_epochs = 50

disc = Discriminator(embed_dim).to(device)
gen = Generator(z_dim, embed_dim).to(device)
fixed_noise = torch.randn((batch_size, z_dim)).to(device)
transforms = transforms.Compose(
    [
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,)),
    ]
)
# Out:
# 2024-03-29 17:02:31.480712: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Preprocessing Data

# %%
#Limit number of rows for experimentation
df = pd.read_csv('author_csv.csv')
num_rows = len(df)
df = df[:num_rows]
df
# Out:
#        Unnamed: 0  author_labels  \
# 0               0              1
# 1               1              1
# 2               2              1
# 3               3              1
# 4               4              1
# ...           ...            ...
# 32592       32592              0
# 32593       32593              0
# 32594       32594              0
# 32595       32595              0
# 32596       32596              0
#
#                                               cls_tokens
# 0      [0.278237104415893, -0.33750003576278603, 0.84...
# 1      [-0.13946822285652102, 0.093057677149772, 0.73...
# 2      [-1.493581295013427, 0.748962104320526, 1.0086...
# 3      [-0.9141901135444641, 0.6804959774017331, 0.90...
# 4      [0.040547348558902005, 0.08085644245147701, 1....
# ...                                                  ...
# 32592  [0.036508537828922, -0.9830706119537351, 0.194...
# 32593  [-0.49513417482376104, -0.42453348636627203, 0...
# 32594  [-0.6720252633094781, -0.37544131278991705, 2....
# 32595  [0.153745874762535, -0.533583104610443, -0.371...
# 32596  [-0.7284083962440491, -0.38280051946640004, -0...
#
# [32597 rows x 3 columns]

# %%
df['author_labels'].value_counts()
# Out:
# author_labels
# 1    27903
# 0     2352
# 2     2342
# Name: count, dtype: int64

# %%
# Load the text lines

embeddings = df['cls_tokens']

#Turn EagerTensors list to Normal Tensors list
embeddings_pytorch = [torch.tensor(np.array(ast.literal_eval(e)), dtype=torch.float32) for e in embeddings]

# Convert list of tensors to a single tensor
embeddings_tensor = torch.stack(embeddings_pytorch).squeeze(1)  # Adjust dimensions as needed

embeddings_tensor
# Out:
# tensor([[ 0.2782, -0.3375,  0.8478,  ..., -0.7637, -0.5338,  0.3607],
#         [-0.1395,  0.0931,  0.7390,  ...,  0.8308, -0.3973,  1.1339],
#         [-1.4936,  0.7490,  1.0087,  ...,  1.5033, -1.2829, -0.5658],
#         ...,
#         [-0.6720, -0.3754,  2.1211,  ...,  1.0377, -0.6048, -0.7254],
#         [ 0.1537, -0.5336, -0.3715,  ...,  1.6371,  0.6499, -0.5228],
#         [-0.7284, -0.3828, -0.2024,  ...,  1.4613,  0.1921,  1.5803]])

# %%
embeddings_tensor.shape
# Out:
# torch.Size([32597, 768])

# %%
embeddings = embeddings_tensor

# %%
#Initialize Dataset
embeddings = embeddings_tensor 

# Instantiate the custom dataset
dataset = CustomDataset(embeddings)

# %% [markdown]
# # Training the SGAN Model

# %%
from keras.layers import Layer
from keras import backend as K

#Ended up not using either of these custom layers, so ignore for now
class CustomActivationLayer(Layer):
    def call(self, inputs):
        logexpsum = K.sum(K.exp(inputs), axis=-1, keepdims=True)
        result = logexpsum / (logexpsum + 1.0)
        return result

    def compute_output_shape(self, input_shape):
        # Assuming your layer does not change the input shape
        return input_shape

# %%
import tensorflow as tf

class CustomActivationLayer(Layer):
    def call(self, inputs):
        logexpsum = tf.reduce_sum(tf.exp(inputs), axis=-1, keepdims=True)
        result = logexpsum / (logexpsum + 1.0)
        return result

    def compute_output_shape(self, input_shape):
        # Assuming your layer does not change the input shape
        return input_shape

# %%
X = embeddings_tensor
y = df['author_labels'].to_numpy()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=6)
print(X_test.shape)
print(y_test.shape)
# Out:
# torch.Size([8150, 768])
# (8150,)

# %% [markdown]
# The next code block contains all the helper functions and the training script. The main functions to look at are the
# define_discriminator, define_generator, and define_gan functions. They contain the model architecture for the discriminator and generator functions.

# %%
lr = 0.0002
n_samples = 1000
n_epochs = 2
loss_var_threshold = 0.01

# define the standalone supervised and unsupervised discriminator models
def define_discriminator(in_shape=(MAX_LENGTH,), n_classes=df['author_labels'].nunique()):
    
  # Embedding input
  in_image = Input(shape=in_shape)

  # downsample
  fe = Dense(units=100, activation='sigmoid')(in_image)
  fe = LeakyReLU(negative_slope=0.2)(fe)

  # downsample
  fe = Dense(units=100, activation='sigmoid')(in_image)
  fe = LeakyReLU(negative_slope=0.2)(fe)
    
  # dropout
  fe = Dropout(0.2)(fe)

  # output layer nodes
  fe = Dense(n_classes)(fe)
    
  # supervised output
  c_out_layer = Activation('softmax')(fe)
    
  # define and compile supervised discriminator model
  c_model = Model(in_image, c_out_layer)
  c_model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=lr, beta_1=0.5), metrics=['accuracy'])
    
  # unsupervised output
  d_out_layer = Dense(units = 1, activation = 'sigmoid')(fe)
    
  # define and compile unsupervised discriminator model
  d_model = Model(in_image, d_out_layer)
  d_model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=lr, beta_1=0.5), metrics = ['accuracy'])
  d_model.trainable = True
  c_model.trainable = True
    
  return d_model, c_model

# define the standalone generator model
def define_generator(latent_dim, n_outputs=MAX_LENGTH):
	model = Sequential()
	model.add(Dense(200, activation='sigmoid', kernel_initializer='he_uniform', input_dim=latent_dim))
	model.add(Dense(100, activation='sigmoid'))
	model.add(Dense(n_outputs, activation='relu'))
	return model

# define the combined generator and discriminator model, for updating the generator
def define_gan(generator, discriminator):
    # Ensure the discriminator's parameters are not trainable in the combined model
    discriminator.trainable = False
    
    # Create a new input layer for the GAN (noise sample)
    gan_input = Input(shape=(latent_dim,))
    
    # Output of the generator
    generator_output = generator(gan_input)
    
    # Output of the discriminator (takes generator's output as input)
    gan_output = discriminator(generator_output)
    
    # Define the GAN model
    gan = Model(gan_input, gan_output)
    
    # Compile the GAN model
    optimizer = Adam(learning_rate=lr)
    gan.compile(optimizer=optimizer, loss='binary_crossentropy')
    
    return gan


# load the embeddings and classifications
def load_real_samples(X,y):
	print(X.shape, y.shape)
	return [X, y]

# select a supervised subset of the dataset, ensures classes are balanced
def select_supervised_samples(dataset, n_samples=n_samples, n_classes=df['author_labels'].nunique()):
    X, y = dataset
    n_per_class = int(n_samples / n_classes)
    X_samples = []
    y_samples = []

    
    for class_index in range(n_classes):
        
        # Find the indices of all samples belonging to the current class
        class_indices = np.where(y == class_index)[0]
        
        # Randomly choose n_per_class indices for this class
        selected_indices = np.random.choice(class_indices, n_per_class, replace=False)
        # Append the selected samples to the lists
        X_samples.append(X[selected_indices])
        y_samples.append(y[selected_indices])
    
    # Concatenate all selected samples
    X_samples = np.concatenate(X_samples, axis=0)
    y_samples = np.concatenate(y_samples, axis=0)
    return X_samples, y_samples

    
def generate_real_samples(dataset, n_samples):
    features, labels = dataset
    # Generate random indices
    indices = np.random.choice(features.shape[0], n_samples, replace=False)
    # Select a random subset of features and labels using the indices
    X = features[indices]
    labels = labels[indices]
    # Generate class labels (assuming you want all ones for real samples)
    y = np.ones((n_samples, 1))
    return [X, labels], y


# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples):
	# generate points in the latent space
	z_input = randn(latent_dim * n_samples)
	# reshape into a batch of inputs for the network
	z_input = z_input.reshape(n_samples, latent_dim)
	return z_input

# use the generator to generate n fake examples, with class labels
def generate_fake_samples(generator, latent_dim, n_samples):
	# generate points in latent space
	z_input = generate_latent_points(latent_dim, n_samples)
	# predict outputs
	images = generator.predict(z_input)
	# create class labels
	y = zeros((n_samples, 1))
	return images, y

# generate samples and save as a plot and save the model
def summarize_performance(step, g_model, c_model, latent_dim, dataset, acc_list, n_samples=100):
    
	# prepare fake examples
	X, _ = generate_fake_samples(g_model, latent_dim, n_samples)
    
	# scale from [-1,1] to [0,1]
	X = (X + 1) / 2.0
    
	# evaluate the classifier model
	X, y = dataset
	_, acc = c_model.evaluate(X, y, verbose=0)
	acc_list.append(acc)
	print('Classifier Accuracy: %.3f%%' % (acc * 100))
    
	# save the generator model
	filename2 = 'g_model_%04d.h5' % (step+1)
	g_model.save(filename2)
    
	# save the classifier model
	filename3 = 'c_model_%04d.h5' % (step+1)
	c_model.save(filename3)
	print('>Saved:  %s and %s' % (filename2, filename3))

# train the generator and discriminator
def train(g_model, d_model, c_model, gan_model, dataset, latent_dim, acc_list, n_epochs=n_epochs, n_batch=100):
    print(f'Latent dimensions: {latent_dim}\n-------------')
    # Initialize lists to track losses
    c_losses, d_losses, g_losses = [], [], []
    loss_variance_threshold = loss_var_threshold  # Set a threshold for the variance
    min_epochs = 5  # Set a minimum number of epochs to prevent stopping too early
    
    # select supervised dataset
    X_sup, y_sup = select_supervised_samples(dataset)
    print(X_sup.shape, y_sup.shape)
    
    # calculate the number of batches per training epoch
    bat_per_epo = int(dataset[0].shape[0] / n_batch)
    
    # calculate the number of training iterations
    n_steps = bat_per_epo * n_epochs
    
    # calculate the size of half a batch of samples
    half_batch = int(n_batch / 2)
    print('n_epochs=%d, n_batch=%d, 1/2=%d, b/e=%d, steps=%d' % (n_epochs, n_batch, half_batch, bat_per_epo, n_steps))
    
    # manually enumerate epochs
    for i in range(n_steps):
        
        # update supervised discriminator (c)
        [Xsup_real, ysup_real], _ = generate_real_samples([X_sup, y_sup], n_batch)
        c_loss, c_acc = c_model.train_on_batch(Xsup_real, ysup_real)
        
        # update unsupervised discriminator (d) on real samples
        [X_real, _], y_real = generate_real_samples(dataset, n_batch)
        d_loss1, d_acc1 = d_model.train_on_batch(X_real, y_real)  # Capture loss and accuracy
        
        # update unsupervised discriminator (d) on fake samples
        X_fake, y_fake = generate_fake_samples(g_model, latent_dim, n_batch)
        d_loss2, d_acc2 = d_model.train_on_batch(X_fake, y_fake)  # Capture loss and accuracy

        
        # update generator (g)
        X_gan, y_gan = generate_latent_points(latent_dim, n_batch), ones((n_batch, 1))
        g_loss = gan_model.train_on_batch(X_gan, y_gan)
        
        # summarize loss on this batch
        print('>%d, c(loss and accuracy)[%.3f,%.0f], d(loss on real and fake)[%.3f,%.3f], d(acc on real and fake)[%.3f,%.3f], g(loss)[%.3f]' % (i+1, c_loss, c_acc*100, d_loss1, d_loss2, d_acc1 * 100, d_acc2 * 100, g_loss))
        
        # evaluate the model performance every so often
        if (i+1) % (100) == 0:
            summarize_performance(i, g_model, c_model, latent_dim, dataset, acc_list)
    
        # At the end of each epoch (or defined interval) in training loop:
        c_losses.append(c_loss)
        d_losses.append((d_loss1 + d_loss2) / 2)
        g_losses.append(g_loss)
        
        # Calculate the variance of the last N losses to check for stability
        if len(c_losses) > min_epochs * (i + 1):  # Ensure we have enough data to make a meaningful decision
            recent_c_var = np.var(c_losses[-min_epochs:])
            recent_d_var = np.var(d_losses[-min_epochs:])
            recent_g_var = np.var(g_losses[-min_epochs:])
            
            # Check if all losses have stabilized
            if recent_c_var < loss_variance_threshold and recent_d_var < loss_variance_threshold and recent_g_var < loss_variance_threshold:
                print(f"Stopping training at epoch {i+1} due to stabilized losses.")
                break

# %%
def def_models(latent_dim):
    d_model, c_model = define_discriminator()
    g_model = define_generator(latent_dim)
    gan_model = define_gan(g_model, d_model)
    return d_model, c_model, g_model, gan_model

def train_script(latent_dim):
    d_model, c_model, g_model, gan_model = def_models(latent_dim)

    train(g_model, d_model, c_model, gan_model, dataset, latent_dim, acc_list)

# %%
#accuracy list for each epochs
acc_list = []
# size of the latent space
latent_dim = 100
# create the discriminator models
d_model, c_model = define_discriminator()

# create the generator
g_model = define_generator(latent_dim)

# create the gan
gan_model = define_gan(g_model, d_model)

# load embedding data
dataset = load_real_samples(X_train,y_train)
c_model.summary() #Summary of supervised discriminator

d_model.summary() #Summary of unsupervised discriminator
# Out:
# torch.Size([24447, 768]) (24447,)
# Model: "functional_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 768)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 100)            │        76,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 3)              │           303 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 3)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 77,203 (301.57 KB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 77,203 (301.57 KB)
# Model: "functional_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 768)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 100)            │        76,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 3)              │           303 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 77,207 (301.59 KB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 77,207 (301.59 KB)

# %%
train(g_model, d_model, c_model, gan_model, dataset, latent_dim, acc_list)
# Out:
# Latent dimensions: 100
# -------------
# (999, 768) (999,)
# n_epochs=2, n_batch=100, 1/2=50, b/e=244, steps=488
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# >1, c(loss and accuracy)[1.263,33], d(loss on real and fake)[0.968,0.753], d(acc on real and fake)[3.000,50.500], g(loss)[0.854]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >2, c(loss and accuracy)[1.210,35], d(loss on real and fake)[0.817,0.756], d(acc on real and fake)[35.000,48.000], g(loss)[0.865]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >3, c(loss and accuracy)[1.205,38], d(loss on real and fake)[0.799,0.763], d(acc on real and fake)[39.000,47.667], g(loss)[0.859]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >4, c(loss and accuracy)[1.223,35], d(loss on real and fake)[0.790,0.766], d(acc on real and fake)[41.714,46.875], g(loss)[0.845]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >5, c(loss and accuracy)[1.235,35], d(loss on real and fake)[0.785,0.768], d(acc on real and fake)[42.444,46.500], g(loss)[0.831]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >6, c(loss and accuracy)[1.231,35], d(loss on real and fake)[0.787,0.775], d(acc on real and fake)[42.455,44.750], g(loss)[0.817]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >7, c(loss and accuracy)[1.231,36], d(loss on real and fake)[0.788,0.779], d(acc on real and fake)[41.692,44.000], g(loss)[0.805]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >8, c(loss and accuracy)[1.247,35], d(loss on real and fake)[0.790,0.783], d(acc on real and fake)[41.533,42.312], g(loss)[0.796]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >9, c(loss and accuracy)[1.245,35], d(loss on real and fake)[0.792,0.786], d(acc on real and fake)[40.118,41.222], g(loss)[0.787]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >10, c(loss and accuracy)[1.237,36], d(loss on real and fake)[0.796,0.792], d(acc on real and fake)[39.158,39.300], g(loss)[0.778]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >11, c(loss and accuracy)[1.234,35], d(loss on real and fake)[0.802,0.799], d(acc on real and fake)[37.619,37.182], g(loss)[0.768]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >12, c(loss and accuracy)[1.231,36], d(loss on real and fake)[0.806,0.804], d(acc on real and fake)[35.609,35.333], g(loss)[0.758]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >13, c(loss and accuracy)[1.233,36], d(loss on real and fake)[0.811,0.810], d(acc on real and fake)[33.960,33.500], g(loss)[0.750]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >14, c(loss and accuracy)[1.238,35], d(loss on real and fake)[0.815,0.813], d(acc on real and fake)[32.481,32.000], g(loss)[0.741]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >15, c(loss and accuracy)[1.239,35], d(loss on real and fake)[0.818,0.818], d(acc on real and fake)[31.000,30.467], g(loss)[0.732]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >16, c(loss and accuracy)[1.237,35], d(loss on real and fake)[0.822,0.822], d(acc on real and fake)[29.742,29.125], g(loss)[0.722]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >17, c(loss and accuracy)[1.235,35], d(loss on real and fake)[0.826,0.827], d(acc on real and fake)[28.333,27.765], g(loss)[0.714]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >18, c(loss and accuracy)[1.238,35], d(loss on real and fake)[0.831,0.831], d(acc on real and fake)[27.171,26.806], g(loss)[0.706]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >19, c(loss and accuracy)[1.237,35], d(loss on real and fake)[0.835,0.836], d(acc on real and fake)[26.243,25.632], g(loss)[0.696]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >20, c(loss and accuracy)[1.238,35], d(loss on real and fake)[0.839,0.841], d(acc on real and fake)[25.103,24.650], g(loss)[0.688]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >21, c(loss and accuracy)[1.232,35], d(loss on real and fake)[0.843,0.845], d(acc on real and fake)[24.220,23.667], g(loss)[0.680]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >22, c(loss and accuracy)[1.231,35], d(loss on real and fake)[0.848,0.850], d(acc on real and fake)[23.209,22.750], g(loss)[0.672]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >23, c(loss and accuracy)[1.232,35], d(loss on real and fake)[0.853,0.855], d(acc on real and fake)[22.400,21.957], g(loss)[0.665]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >24, c(loss and accuracy)[1.228,36], d(loss on real and fake)[0.857,0.860], d(acc on real and fake)[21.638,21.188], g(loss)[0.657]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >25, c(loss and accuracy)[1.230,35], d(loss on real and fake)[0.862,0.864], d(acc on real and fake)[20.816,20.420], g(loss)[0.650]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >26, c(loss and accuracy)[1.232,35], d(loss on real and fake)[0.866,0.868], d(acc on real and fake)[20.196,19.808], g(loss)[0.643]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >27, c(loss and accuracy)[1.234,35], d(loss on real and fake)[0.869,0.873], d(acc on real and fake)[19.547,19.185], g(loss)[0.636]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >28, c(loss and accuracy)[1.235,35], d(loss on real and fake)[0.874,0.877], d(acc on real and fake)[18.909,18.571], g(loss)[0.629]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >29, c(loss and accuracy)[1.235,35], d(loss on real and fake)[0.878,0.881], d(acc on real and fake)[18.386,18.069], g(loss)[0.622]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >30, c(loss and accuracy)[1.241,35], d(loss on real and fake)[0.882,0.886], d(acc on real and fake)[17.814,17.517], g(loss)[0.615]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >31, c(loss and accuracy)[1.239,35], d(loss on real and fake)[0.887,0.890], d(acc on real and fake)[17.311,17.032], g(loss)[0.609]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >32, c(loss and accuracy)[1.238,35], d(loss on real and fake)[0.891,0.894], d(acc on real and fake)[16.857,16.594], g(loss)[0.603]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >33, c(loss and accuracy)[1.235,35], d(loss on real and fake)[0.895,0.899], d(acc on real and fake)[16.446,16.212], g(loss)[0.596]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >34, c(loss and accuracy)[1.233,35], d(loss on real and fake)[0.900,0.903], d(acc on real and fake)[16.015,15.794], g(loss)[0.590]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >35, c(loss and accuracy)[1.233,35], d(loss on real and fake)[0.904,0.908], d(acc on real and fake)[15.652,15.429], g(loss)[0.584]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >36, c(loss and accuracy)[1.235,35], d(loss on real and fake)[0.909,0.913], d(acc on real and fake)[15.254,15.042], g(loss)[0.577]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >37, c(loss and accuracy)[1.238,35], d(loss on real and fake)[0.913,0.917], d(acc on real and fake)[14.904,14.703], g(loss)[0.571]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >38, c(loss and accuracy)[1.238,35], d(loss on real and fake)[0.918,0.922], d(acc on real and fake)[14.573,14.382], g(loss)[0.566]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >39, c(loss and accuracy)[1.237,35], d(loss on real and fake)[0.922,0.926], d(acc on real and fake)[14.273,14.090], g(loss)[0.560]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >40, c(loss and accuracy)[1.239,35], d(loss on real and fake)[0.927,0.931], d(acc on real and fake)[13.962,13.788], g(loss)[0.555]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >41, c(loss and accuracy)[1.237,35], d(loss on real and fake)[0.932,0.936], d(acc on real and fake)[13.728,13.561], g(loss)[0.549]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >42, c(loss and accuracy)[1.236,35], d(loss on real and fake)[0.937,0.941], d(acc on real and fake)[13.482,13.321], g(loss)[0.544]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >43, c(loss and accuracy)[1.235,35], d(loss on real and fake)[0.941,0.945], d(acc on real and fake)[13.212,13.058], g(loss)[0.539]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >44, c(loss and accuracy)[1.235,35], d(loss on real and fake)[0.946,0.950], d(acc on real and fake)[12.954,12.807], g(loss)[0.533]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >45, c(loss and accuracy)[1.235,35], d(loss on real and fake)[0.950,0.955], d(acc on real and fake)[12.764,12.622], g(loss)[0.528]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >46, c(loss and accuracy)[1.236,35], d(loss on real and fake)[0.955,0.959], d(acc on real and fake)[12.527,12.391], g(loss)[0.523]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >47, c(loss and accuracy)[1.235,35], d(loss on real and fake)[0.959,0.963], d(acc on real and fake)[12.290,12.160], g(loss)[0.519]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >48, c(loss and accuracy)[1.234,35], d(loss on real and fake)[0.963,0.968], d(acc on real and fake)[12.042,11.917], g(loss)[0.514]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >49, c(loss and accuracy)[1.233,35], d(loss on real and fake)[0.968,0.972], d(acc on real and fake)[11.876,11.755], g(loss)[0.509]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >50, c(loss and accuracy)[1.232,35], d(loss on real and fake)[0.972,0.977], d(acc on real and fake)[11.727,11.610], g(loss)[0.505]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >51, c(loss and accuracy)[1.233,35], d(loss on real and fake)[0.977,0.981], d(acc on real and fake)[11.545,11.431], g(loss)[0.500]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >52, c(loss and accuracy)[1.232,35], d(loss on real and fake)[0.981,0.985], d(acc on real and fake)[11.369,11.260], g(loss)[0.496]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >53, c(loss and accuracy)[1.232,35], d(loss on real and fake)[0.985,0.989], d(acc on real and fake)[11.229,11.123], g(loss)[0.492]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >54, c(loss and accuracy)[1.232,35], d(loss on real and fake)[0.989,0.993], d(acc on real and fake)[11.075,10.972], g(loss)[0.487]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >55, c(loss and accuracy)[1.235,35], d(loss on real and fake)[0.993,0.998], d(acc on real and fake)[10.936,10.836], g(loss)[0.483]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >56, c(loss and accuracy)[1.235,35], d(loss on real and fake)[0.997,1.002], d(acc on real and fake)[10.802,10.705], g(loss)[0.479]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >57, c(loss and accuracy)[1.234,35], d(loss on real and fake)[1.002,1.006], d(acc on real and fake)[10.637,10.544], g(loss)[0.475]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >58, c(loss and accuracy)[1.233,35], d(loss on real and fake)[1.006,1.010], d(acc on real and fake)[10.513,10.422], g(loss)[0.471]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >59, c(loss and accuracy)[1.236,35], d(loss on real and fake)[1.010,1.015], d(acc on real and fake)[10.376,10.288], g(loss)[0.467]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >60, c(loss and accuracy)[1.236,35], d(loss on real and fake)[1.014,1.019], d(acc on real and fake)[10.244,10.158], g(loss)[0.463]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >61, c(loss and accuracy)[1.236,35], d(loss on real and fake)[1.018,1.023], d(acc on real and fake)[10.157,10.074], g(loss)[0.460]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >62, c(loss and accuracy)[1.235,35], d(loss on real and fake)[1.022,1.027], d(acc on real and fake)[10.008,9.927], g(loss)[0.456]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >63, c(loss and accuracy)[1.235,35], d(loss on real and fake)[1.027,1.031], d(acc on real and fake)[9.904,9.825], g(loss)[0.452]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >64, c(loss and accuracy)[1.234,35], d(loss on real and fake)[1.031,1.035], d(acc on real and fake)[9.787,9.711], g(loss)[0.449]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >65, c(loss and accuracy)[1.234,35], d(loss on real and fake)[1.035,1.039], d(acc on real and fake)[9.659,9.585], g(loss)[0.445]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >66, c(loss and accuracy)[1.233,35], d(loss on real and fake)[1.039,1.044], d(acc on real and fake)[9.550,9.477], g(loss)[0.442]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >67, c(loss and accuracy)[1.232,35], d(loss on real and fake)[1.043,1.048], d(acc on real and fake)[9.429,9.358], g(loss)[0.438]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >68, c(loss and accuracy)[1.233,35], d(loss on real and fake)[1.047,1.052], d(acc on real and fake)[9.311,9.243], g(loss)[0.435]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >69, c(loss and accuracy)[1.233,35], d(loss on real and fake)[1.051,1.056], d(acc on real and fake)[9.212,9.145], g(loss)[0.432]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >70, c(loss and accuracy)[1.233,35], d(loss on real and fake)[1.055,1.060], d(acc on real and fake)[9.129,9.064], g(loss)[0.428]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >71, c(loss and accuracy)[1.232,35], d(loss on real and fake)[1.059,1.064], d(acc on real and fake)[9.035,8.972], g(loss)[0.425]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >72, c(loss and accuracy)[1.233,35], d(loss on real and fake)[1.063,1.068], d(acc on real and fake)[8.930,8.868], g(loss)[0.422]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >73, c(loss and accuracy)[1.232,35], d(loss on real and fake)[1.067,1.072], d(acc on real and fake)[8.848,8.788], g(loss)[0.419]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >74, c(loss and accuracy)[1.234,35], d(loss on real and fake)[1.071,1.076], d(acc on real and fake)[8.755,8.696], g(loss)[0.416]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >75, c(loss and accuracy)[1.233,35], d(loss on real and fake)[1.075,1.079], d(acc on real and fake)[8.685,8.627], g(loss)[0.413]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >76, c(loss and accuracy)[1.234,35], d(loss on real and fake)[1.079,1.083], d(acc on real and fake)[8.596,8.539], g(loss)[0.410]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >77, c(loss and accuracy)[1.233,35], d(loss on real and fake)[1.082,1.087], d(acc on real and fake)[8.516,8.461], g(loss)[0.407]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >78, c(loss and accuracy)[1.234,35], d(loss on real and fake)[1.086,1.091], d(acc on real and fake)[8.452,8.397], g(loss)[0.404]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >79, c(loss and accuracy)[1.234,35], d(loss on real and fake)[1.090,1.095], d(acc on real and fake)[8.350,8.297], g(loss)[0.402]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >80, c(loss and accuracy)[1.235,35], d(loss on real and fake)[1.094,1.099], d(acc on real and fake)[8.277,8.225], g(loss)[0.399]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >81, c(loss and accuracy)[1.233,35], d(loss on real and fake)[1.098,1.102], d(acc on real and fake)[8.193,8.142], g(loss)[0.396]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >82, c(loss and accuracy)[1.234,35], d(loss on real and fake)[1.101,1.106], d(acc on real and fake)[8.092,8.043], g(loss)[0.393]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >83, c(loss and accuracy)[1.234,35], d(loss on real and fake)[1.105,1.110], d(acc on real and fake)[8.030,7.982], g(loss)[0.391]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >84, c(loss and accuracy)[1.233,35], d(loss on real and fake)[1.109,1.114], d(acc on real and fake)[7.946,7.899], g(loss)[0.388]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >85, c(loss and accuracy)[1.235,35], d(loss on real and fake)[1.113,1.117], d(acc on real and fake)[7.917,7.871], g(loss)[0.386]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >86, c(loss and accuracy)[1.235,35], d(loss on real and fake)[1.116,1.121], d(acc on real and fake)[7.836,7.791], g(loss)[0.383]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >87, c(loss and accuracy)[1.234,35], d(loss on real and fake)[1.119,1.124], d(acc on real and fake)[7.798,7.753], g(loss)[0.380]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >88, c(loss and accuracy)[1.234,34], d(loss on real and fake)[1.123,1.128], d(acc on real and fake)[7.726,7.682], g(loss)[0.378]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >89, c(loss and accuracy)[1.234,34], d(loss on real and fake)[1.127,1.131], d(acc on real and fake)[7.689,7.646], g(loss)[0.376]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >90, c(loss and accuracy)[1.234,34], d(loss on real and fake)[1.130,1.135], d(acc on real and fake)[7.620,7.578], g(loss)[0.373]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >91, c(loss and accuracy)[1.232,35], d(loss on real and fake)[1.134,1.138], d(acc on real and fake)[7.564,7.522], g(loss)[0.371]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >92, c(loss and accuracy)[1.230,35], d(loss on real and fake)[1.137,1.141], d(acc on real and fake)[7.519,7.478], g(loss)[0.369]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >93, c(loss and accuracy)[1.230,35], d(loss on real and fake)[1.140,1.145], d(acc on real and fake)[7.476,7.435], g(loss)[0.366]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >94, c(loss and accuracy)[1.230,35], d(loss on real and fake)[1.144,1.148], d(acc on real and fake)[7.412,7.372], g(loss)[0.364]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >95, c(loss and accuracy)[1.230,35], d(loss on real and fake)[1.147,1.151], d(acc on real and fake)[7.354,7.316], g(loss)[0.362]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >96, c(loss and accuracy)[1.229,35], d(loss on real and fake)[1.150,1.154], d(acc on real and fake)[7.304,7.266], g(loss)[0.360]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >97, c(loss and accuracy)[1.229,35], d(loss on real and fake)[1.153,1.158], d(acc on real and fake)[7.254,7.216], g(loss)[0.357]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >98, c(loss and accuracy)[1.229,35], d(loss on real and fake)[1.157,1.161], d(acc on real and fake)[7.210,7.173], g(loss)[0.355]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >99, c(loss and accuracy)[1.228,35], d(loss on real and fake)[1.160,1.164], d(acc on real and fake)[7.157,7.121], g(loss)[0.353]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >100, c(loss and accuracy)[1.228,35], d(loss on real and fake)[1.163,1.167], d(acc on real and fake)[7.116,7.080], g(loss)[0.351]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Classifier Accuracy: 73.952%
# >Saved:  g_model_0100.h5 and c_model_0100.h5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >101, c(loss and accuracy)[0.839,74], d(loss on real and fake)[1.166,1.170], d(acc on real and fake)[7.090,7.054], g(loss)[0.349]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# >102, c(loss and accuracy)[0.840,74], d(loss on real and fake)[1.169,1.173], d(acc on real and fake)[7.044,7.010], g(loss)[0.347]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >103, c(loss and accuracy)[0.840,73], d(loss on real and fake)[1.172,1.177], d(acc on real and fake)[7.010,6.976], g(loss)[0.345]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >104, c(loss and accuracy)[0.841,73], d(loss on real and fake)[1.176,1.180], d(acc on real and fake)[6.971,6.938], g(loss)[0.343]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >105, c(loss and accuracy)[0.841,73], d(loss on real and fake)[1.179,1.183], d(acc on real and fake)[6.943,6.910], g(loss)[0.341]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >106, c(loss and accuracy)[0.842,73], d(loss on real and fake)[1.182,1.186], d(acc on real and fake)[6.910,6.877], g(loss)[0.339]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >107, c(loss and accuracy)[0.843,73], d(loss on real and fake)[1.185,1.189], d(acc on real and fake)[6.864,6.832], g(loss)[0.338]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >108, c(loss and accuracy)[0.843,73], d(loss on real and fake)[1.188,1.192], d(acc on real and fake)[6.819,6.787], g(loss)[0.336]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >109, c(loss and accuracy)[0.844,72], d(loss on real and fake)[1.191,1.195], d(acc on real and fake)[6.774,6.743], g(loss)[0.334]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >110, c(loss and accuracy)[0.844,72], d(loss on real and fake)[1.194,1.198], d(acc on real and fake)[6.731,6.700], g(loss)[0.332]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >111, c(loss and accuracy)[0.845,72], d(loss on real and fake)[1.197,1.201], d(acc on real and fake)[6.683,6.653], g(loss)[0.330]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >112, c(loss and accuracy)[0.845,72], d(loss on real and fake)[1.200,1.204], d(acc on real and fake)[6.637,6.607], g(loss)[0.329]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >113, c(loss and accuracy)[0.846,72], d(loss on real and fake)[1.203,1.207], d(acc on real and fake)[6.613,6.584], g(loss)[0.327]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >114, c(loss and accuracy)[0.846,72], d(loss on real and fake)[1.205,1.209], d(acc on real and fake)[6.568,6.539], g(loss)[0.325]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >115, c(loss and accuracy)[0.847,72], d(loss on real and fake)[1.208,1.212], d(acc on real and fake)[6.533,6.504], g(loss)[0.324]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >116, c(loss and accuracy)[0.847,72], d(loss on real and fake)[1.211,1.215], d(acc on real and fake)[6.494,6.466], g(loss)[0.322]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >117, c(loss and accuracy)[0.848,71], d(loss on real and fake)[1.214,1.217], d(acc on real and fake)[6.459,6.432], g(loss)[0.320]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >118, c(loss and accuracy)[0.848,71], d(loss on real and fake)[1.216,1.220], d(acc on real and fake)[6.430,6.403], g(loss)[0.319]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >119, c(loss and accuracy)[0.849,71], d(loss on real and fake)[1.219,1.223], d(acc on real and fake)[6.392,6.366], g(loss)[0.317]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >120, c(loss and accuracy)[0.849,71], d(loss on real and fake)[1.222,1.226], d(acc on real and fake)[6.356,6.329], g(loss)[0.316]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >121, c(loss and accuracy)[0.850,71], d(loss on real and fake)[1.225,1.229], d(acc on real and fake)[6.315,6.289], g(loss)[0.314]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >122, c(loss and accuracy)[0.850,71], d(loss on real and fake)[1.227,1.231], d(acc on real and fake)[6.296,6.270], g(loss)[0.312]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >123, c(loss and accuracy)[0.851,71], d(loss on real and fake)[1.230,1.234], d(acc on real and fake)[6.265,6.240], g(loss)[0.311]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >124, c(loss and accuracy)[0.851,70], d(loss on real and fake)[1.233,1.236], d(acc on real and fake)[6.223,6.198], g(loss)[0.309]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >125, c(loss and accuracy)[0.852,70], d(loss on real and fake)[1.235,1.239], d(acc on real and fake)[6.177,6.152], g(loss)[0.308]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >126, c(loss and accuracy)[0.852,70], d(loss on real and fake)[1.238,1.241], d(acc on real and fake)[6.143,6.119], g(loss)[0.306]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >127, c(loss and accuracy)[0.853,70], d(loss on real and fake)[1.240,1.244], d(acc on real and fake)[6.115,6.091], g(loss)[0.305]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >128, c(loss and accuracy)[0.853,70], d(loss on real and fake)[1.243,1.246], d(acc on real and fake)[6.090,6.066], g(loss)[0.304]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >129, c(loss and accuracy)[0.854,70], d(loss on real and fake)[1.245,1.249], d(acc on real and fake)[6.062,6.039], g(loss)[0.302]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >130, c(loss and accuracy)[0.854,70], d(loss on real and fake)[1.248,1.251], d(acc on real and fake)[6.039,6.015], g(loss)[0.301]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >131, c(loss and accuracy)[0.855,69], d(loss on real and fake)[1.250,1.254], d(acc on real and fake)[6.019,5.996], g(loss)[0.300]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >132, c(loss and accuracy)[0.855,69], d(loss on real and fake)[1.253,1.256], d(acc on real and fake)[6.008,5.985], g(loss)[0.298]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >133, c(loss and accuracy)[0.856,69], d(loss on real and fake)[1.255,1.259], d(acc on real and fake)[5.977,5.955], g(loss)[0.297]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >134, c(loss and accuracy)[0.856,69], d(loss on real and fake)[1.258,1.261], d(acc on real and fake)[5.944,5.922], g(loss)[0.296]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >135, c(loss and accuracy)[0.857,69], d(loss on real and fake)[1.260,1.264], d(acc on real and fake)[5.918,5.896], g(loss)[0.294]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >136, c(loss and accuracy)[0.857,69], d(loss on real and fake)[1.263,1.266], d(acc on real and fake)[5.897,5.875], g(loss)[0.293]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >137, c(loss and accuracy)[0.858,69], d(loss on real and fake)[1.265,1.269], d(acc on real and fake)[5.857,5.836], g(loss)[0.292]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >138, c(loss and accuracy)[0.858,69], d(loss on real and fake)[1.268,1.271], d(acc on real and fake)[5.836,5.815], g(loss)[0.290]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >139, c(loss and accuracy)[0.859,69], d(loss on real and fake)[1.270,1.274], d(acc on real and fake)[5.827,5.806], g(loss)[0.289]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >140, c(loss and accuracy)[0.859,68], d(loss on real and fake)[1.273,1.276], d(acc on real and fake)[5.796,5.775], g(loss)[0.288]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >141, c(loss and accuracy)[0.860,68], d(loss on real and fake)[1.275,1.279], d(acc on real and fake)[5.776,5.755], g(loss)[0.287]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >142, c(loss and accuracy)[0.860,68], d(loss on real and fake)[1.277,1.281], d(acc on real and fake)[5.763,5.743], g(loss)[0.285]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >143, c(loss and accuracy)[0.861,68], d(loss on real and fake)[1.280,1.283], d(acc on real and fake)[5.733,5.713], g(loss)[0.284]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >144, c(loss and accuracy)[0.861,68], d(loss on real and fake)[1.282,1.286], d(acc on real and fake)[5.697,5.677], g(loss)[0.283]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >145, c(loss and accuracy)[0.862,68], d(loss on real and fake)[1.284,1.288], d(acc on real and fake)[5.675,5.655], g(loss)[0.282]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >146, c(loss and accuracy)[0.862,68], d(loss on real and fake)[1.287,1.290], d(acc on real and fake)[5.649,5.630], g(loss)[0.281]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >147, c(loss and accuracy)[0.863,68], d(loss on real and fake)[1.289,1.292], d(acc on real and fake)[5.614,5.595], g(loss)[0.279]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >148, c(loss and accuracy)[0.863,67], d(loss on real and fake)[1.291,1.295], d(acc on real and fake)[5.590,5.571], g(loss)[0.278]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >149, c(loss and accuracy)[0.864,67], d(loss on real and fake)[1.294,1.297], d(acc on real and fake)[5.562,5.544], g(loss)[0.277]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >150, c(loss and accuracy)[0.864,67], d(loss on real and fake)[1.296,1.299], d(acc on real and fake)[5.535,5.517], g(loss)[0.276]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >151, c(loss and accuracy)[0.865,67], d(loss on real and fake)[1.298,1.301], d(acc on real and fake)[5.502,5.483], g(loss)[0.275]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >152, c(loss and accuracy)[0.865,67], d(loss on real and fake)[1.300,1.303], d(acc on real and fake)[5.479,5.461], g(loss)[0.274]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >153, c(loss and accuracy)[0.866,67], d(loss on real and fake)[1.302,1.305], d(acc on real and fake)[5.469,5.451], g(loss)[0.273]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >154, c(loss and accuracy)[0.866,67], d(loss on real and fake)[1.304,1.308], d(acc on real and fake)[5.459,5.442], g(loss)[0.272]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >155, c(loss and accuracy)[0.866,67], d(loss on real and fake)[1.306,1.310], d(acc on real and fake)[5.453,5.435], g(loss)[0.271]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >156, c(loss and accuracy)[0.867,66], d(loss on real and fake)[1.309,1.312], d(acc on real and fake)[5.434,5.417], g(loss)[0.270]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >157, c(loss and accuracy)[0.868,66], d(loss on real and fake)[1.311,1.314], d(acc on real and fake)[5.419,5.401], g(loss)[0.269]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >158, c(loss and accuracy)[0.868,66], d(loss on real and fake)[1.313,1.316], d(acc on real and fake)[5.400,5.383], g(loss)[0.267]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >159, c(loss and accuracy)[0.868,66], d(loss on real and fake)[1.315,1.318], d(acc on real and fake)[5.379,5.362], g(loss)[0.266]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >160, c(loss and accuracy)[0.869,66], d(loss on real and fake)[1.317,1.320], d(acc on real and fake)[5.367,5.350], g(loss)[0.265]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >161, c(loss and accuracy)[0.869,66], d(loss on real and fake)[1.319,1.322], d(acc on real and fake)[5.352,5.335], g(loss)[0.264]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >162, c(loss and accuracy)[0.869,66], d(loss on real and fake)[1.321,1.324], d(acc on real and fake)[5.331,5.315], g(loss)[0.263]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >163, c(loss and accuracy)[0.870,66], d(loss on real and fake)[1.323,1.326], d(acc on real and fake)[5.311,5.294], g(loss)[0.262]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >164, c(loss and accuracy)[0.871,66], d(loss on real and fake)[1.325,1.328], d(acc on real and fake)[5.294,5.277], g(loss)[0.261]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >165, c(loss and accuracy)[0.871,66], d(loss on real and fake)[1.327,1.330], d(acc on real and fake)[5.271,5.255], g(loss)[0.261]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >166, c(loss and accuracy)[0.871,65], d(loss on real and fake)[1.329,1.332], d(acc on real and fake)[5.248,5.232], g(loss)[0.260]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >167, c(loss and accuracy)[0.872,65], d(loss on real and fake)[1.331,1.334], d(acc on real and fake)[5.237,5.222], g(loss)[0.259]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >168, c(loss and accuracy)[0.872,65], d(loss on real and fake)[1.333,1.336], d(acc on real and fake)[5.215,5.199], g(loss)[0.258]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >169, c(loss and accuracy)[0.873,65], d(loss on real and fake)[1.335,1.338], d(acc on real and fake)[5.193,5.178], g(loss)[0.257]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >170, c(loss and accuracy)[0.873,65], d(loss on real and fake)[1.337,1.340], d(acc on real and fake)[5.168,5.153], g(loss)[0.256]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >171, c(loss and accuracy)[0.873,65], d(loss on real and fake)[1.339,1.342], d(acc on real and fake)[5.152,5.137], g(loss)[0.255]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >172, c(loss and accuracy)[0.874,65], d(loss on real and fake)[1.341,1.344], d(acc on real and fake)[5.143,5.128], g(loss)[0.254]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >173, c(loss and accuracy)[0.874,65], d(loss on real and fake)[1.343,1.346], d(acc on real and fake)[5.139,5.124], g(loss)[0.253]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >174, c(loss and accuracy)[0.875,65], d(loss on real and fake)[1.345,1.347], d(acc on real and fake)[5.124,5.109], g(loss)[0.252]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >175, c(loss and accuracy)[0.875,65], d(loss on real and fake)[1.346,1.349], d(acc on real and fake)[5.106,5.091], g(loss)[0.251]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >176, c(loss and accuracy)[0.876,65], d(loss on real and fake)[1.348,1.351], d(acc on real and fake)[5.100,5.085], g(loss)[0.251]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >177, c(loss and accuracy)[0.876,64], d(loss on real and fake)[1.350,1.353], d(acc on real and fake)[5.085,5.071], g(loss)[0.250]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >178, c(loss and accuracy)[0.876,64], d(loss on real and fake)[1.352,1.355], d(acc on real and fake)[5.073,5.059], g(loss)[0.249]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >179, c(loss and accuracy)[0.877,64], d(loss on real and fake)[1.354,1.357], d(acc on real and fake)[5.064,5.050], g(loss)[0.248]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >180, c(loss and accuracy)[0.877,64], d(loss on real and fake)[1.356,1.358], d(acc on real and fake)[5.064,5.050], g(loss)[0.247]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >181, c(loss and accuracy)[0.878,64], d(loss on real and fake)[1.357,1.360], d(acc on real and fake)[5.044,5.030], g(loss)[0.246]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >182, c(loss and accuracy)[0.878,64], d(loss on real and fake)[1.359,1.362], d(acc on real and fake)[5.030,5.016], g(loss)[0.246]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >183, c(loss and accuracy)[0.879,64], d(loss on real and fake)[1.361,1.364], d(acc on real and fake)[5.022,5.008], g(loss)[0.245]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >184, c(loss and accuracy)[0.879,64], d(loss on real and fake)[1.363,1.366], d(acc on real and fake)[5.008,4.995], g(loss)[0.244]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >185, c(loss and accuracy)[0.879,64], d(loss on real and fake)[1.365,1.367], d(acc on real and fake)[4.989,4.976], g(loss)[0.243]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >186, c(loss and accuracy)[0.880,64], d(loss on real and fake)[1.366,1.369], d(acc on real and fake)[4.976,4.962], g(loss)[0.242]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >187, c(loss and accuracy)[0.880,64], d(loss on real and fake)[1.368,1.371], d(acc on real and fake)[4.962,4.949], g(loss)[0.242]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >188, c(loss and accuracy)[0.881,63], d(loss on real and fake)[1.370,1.373], d(acc on real and fake)[4.947,4.934], g(loss)[0.241]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >189, c(loss and accuracy)[0.881,63], d(loss on real and fake)[1.372,1.374], d(acc on real and fake)[4.939,4.926], g(loss)[0.240]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >190, c(loss and accuracy)[0.881,63], d(loss on real and fake)[1.373,1.376], d(acc on real and fake)[4.926,4.913], g(loss)[0.239]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >191, c(loss and accuracy)[0.882,63], d(loss on real and fake)[1.375,1.378], d(acc on real and fake)[4.921,4.908], g(loss)[0.238]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >192, c(loss and accuracy)[0.882,63], d(loss on real and fake)[1.377,1.380], d(acc on real and fake)[4.916,4.904], g(loss)[0.238]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >193, c(loss and accuracy)[0.883,63], d(loss on real and fake)[1.378,1.381], d(acc on real and fake)[4.901,4.889], g(loss)[0.237]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >194, c(loss and accuracy)[0.883,63], d(loss on real and fake)[1.380,1.383], d(acc on real and fake)[4.884,4.871], g(loss)[0.236]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >195, c(loss and accuracy)[0.884,63], d(loss on real and fake)[1.382,1.384], d(acc on real and fake)[4.866,4.854], g(loss)[0.236]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# >196, c(loss and accuracy)[0.884,63], d(loss on real and fake)[1.383,1.386], d(acc on real and fake)[4.854,4.842], g(loss)[0.235]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >197, c(loss and accuracy)[0.884,63], d(loss on real and fake)[1.385,1.387], d(acc on real and fake)[4.840,4.827], g(loss)[0.234]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >198, c(loss and accuracy)[0.885,63], d(loss on real and fake)[1.386,1.389], d(acc on real and fake)[4.838,4.826], g(loss)[0.233]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >199, c(loss and accuracy)[0.885,63], d(loss on real and fake)[1.388,1.391], d(acc on real and fake)[4.836,4.824], g(loss)[0.233]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >200, c(loss and accuracy)[0.885,62], d(loss on real and fake)[1.390,1.392], d(acc on real and fake)[4.817,4.805], g(loss)[0.232]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Classifier Accuracy: 73.952%
# >Saved:  g_model_0200.h5 and c_model_0200.h5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >201, c(loss and accuracy)[0.839,74], d(loss on real and fake)[1.391,1.394], d(acc on real and fake)[4.810,4.799], g(loss)[0.231]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >202, c(loss and accuracy)[0.840,74], d(loss on real and fake)[1.393,1.395], d(acc on real and fake)[4.799,4.787], g(loss)[0.230]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >203, c(loss and accuracy)[0.840,73], d(loss on real and fake)[1.394,1.397], d(acc on real and fake)[4.793,4.781], g(loss)[0.230]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >204, c(loss and accuracy)[0.841,73], d(loss on real and fake)[1.396,1.399], d(acc on real and fake)[4.784,4.772], g(loss)[0.229]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >205, c(loss and accuracy)[0.841,73], d(loss on real and fake)[1.398,1.400], d(acc on real and fake)[4.775,4.763], g(loss)[0.228]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >206, c(loss and accuracy)[0.842,73], d(loss on real and fake)[1.399,1.402], d(acc on real and fake)[4.759,4.748], g(loss)[0.228]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >207, c(loss and accuracy)[0.842,73], d(loss on real and fake)[1.401,1.403], d(acc on real and fake)[4.758,4.746], g(loss)[0.227]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >208, c(loss and accuracy)[0.843,73], d(loss on real and fake)[1.402,1.405], d(acc on real and fake)[4.747,4.736], g(loss)[0.226]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >209, c(loss and accuracy)[0.843,73], d(loss on real and fake)[1.404,1.406], d(acc on real and fake)[4.734,4.722], g(loss)[0.226]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >210, c(loss and accuracy)[0.844,72], d(loss on real and fake)[1.405,1.408], d(acc on real and fake)[4.730,4.719], g(loss)[0.225]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >211, c(loss and accuracy)[0.844,72], d(loss on real and fake)[1.407,1.409], d(acc on real and fake)[4.720,4.709], g(loss)[0.224]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >212, c(loss and accuracy)[0.845,72], d(loss on real and fake)[1.408,1.411], d(acc on real and fake)[4.719,4.708], g(loss)[0.224]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >213, c(loss and accuracy)[0.845,72], d(loss on real and fake)[1.410,1.412], d(acc on real and fake)[4.718,4.707], g(loss)[0.223]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >214, c(loss and accuracy)[0.846,72], d(loss on real and fake)[1.411,1.414], d(acc on real and fake)[4.705,4.694], g(loss)[0.223]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >215, c(loss and accuracy)[0.846,72], d(loss on real and fake)[1.413,1.415], d(acc on real and fake)[4.704,4.693], g(loss)[0.222]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >216, c(loss and accuracy)[0.847,72], d(loss on real and fake)[1.414,1.417], d(acc on real and fake)[4.696,4.685], g(loss)[0.221]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >217, c(loss and accuracy)[0.848,71], d(loss on real and fake)[1.416,1.418], d(acc on real and fake)[4.691,4.680], g(loss)[0.221]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >218, c(loss and accuracy)[0.848,71], d(loss on real and fake)[1.417,1.420], d(acc on real and fake)[4.680,4.670], g(loss)[0.220]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >219, c(loss and accuracy)[0.849,71], d(loss on real and fake)[1.419,1.421], d(acc on real and fake)[4.670,4.660], g(loss)[0.219]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >220, c(loss and accuracy)[0.849,71], d(loss on real and fake)[1.420,1.423], d(acc on real and fake)[4.665,4.655], g(loss)[0.219]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >221, c(loss and accuracy)[0.850,71], d(loss on real and fake)[1.422,1.424], d(acc on real and fake)[4.655,4.645], g(loss)[0.218]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >222, c(loss and accuracy)[0.850,71], d(loss on real and fake)[1.423,1.425], d(acc on real and fake)[4.650,4.640], g(loss)[0.218]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >223, c(loss and accuracy)[0.850,71], d(loss on real and fake)[1.424,1.427], d(acc on real and fake)[4.640,4.630], g(loss)[0.217]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >224, c(loss and accuracy)[0.851,70], d(loss on real and fake)[1.426,1.428], d(acc on real and fake)[4.629,4.618], g(loss)[0.217]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >225, c(loss and accuracy)[0.852,70], d(loss on real and fake)[1.427,1.429], d(acc on real and fake)[4.619,4.609], g(loss)[0.216]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >226, c(loss and accuracy)[0.852,70], d(loss on real and fake)[1.428,1.431], d(acc on real and fake)[4.612,4.602], g(loss)[0.215]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >227, c(loss and accuracy)[0.853,70], d(loss on real and fake)[1.430,1.432], d(acc on real and fake)[4.603,4.593], g(loss)[0.215]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >228, c(loss and accuracy)[0.853,70], d(loss on real and fake)[1.431,1.434], d(acc on real and fake)[4.596,4.586], g(loss)[0.214]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >229, c(loss and accuracy)[0.853,70], d(loss on real and fake)[1.433,1.435], d(acc on real and fake)[4.589,4.579], g(loss)[0.214]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >230, c(loss and accuracy)[0.854,70], d(loss on real and fake)[1.434,1.436], d(acc on real and fake)[4.582,4.572], g(loss)[0.213]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >231, c(loss and accuracy)[0.855,69], d(loss on real and fake)[1.435,1.438], d(acc on real and fake)[4.562,4.552], g(loss)[0.213]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >232, c(loss and accuracy)[0.855,69], d(loss on real and fake)[1.437,1.439], d(acc on real and fake)[4.559,4.550], g(loss)[0.212]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >233, c(loss and accuracy)[0.856,69], d(loss on real and fake)[1.438,1.440], d(acc on real and fake)[4.566,4.556], g(loss)[0.211]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >234, c(loss and accuracy)[0.856,69], d(loss on real and fake)[1.439,1.442], d(acc on real and fake)[4.559,4.549], g(loss)[0.211]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >235, c(loss and accuracy)[0.856,69], d(loss on real and fake)[1.441,1.443], d(acc on real and fake)[4.544,4.534], g(loss)[0.210]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >236, c(loss and accuracy)[0.857,69], d(loss on real and fake)[1.442,1.445], d(acc on real and fake)[4.531,4.521], g(loss)[0.210]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >237, c(loss and accuracy)[0.857,69], d(loss on real and fake)[1.444,1.446], d(acc on real and fake)[4.516,4.506], g(loss)[0.209]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >238, c(loss and accuracy)[0.858,69], d(loss on real and fake)[1.445,1.447], d(acc on real and fake)[4.503,4.494], g(loss)[0.209]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >239, c(loss and accuracy)[0.858,69], d(loss on real and fake)[1.446,1.449], d(acc on real and fake)[4.491,4.481], g(loss)[0.208]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >240, c(loss and accuracy)[0.859,68], d(loss on real and fake)[1.448,1.450], d(acc on real and fake)[4.478,4.469], g(loss)[0.208]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >241, c(loss and accuracy)[0.859,68], d(loss on real and fake)[1.449,1.451], d(acc on real and fake)[4.468,4.459], g(loss)[0.207]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >242, c(loss and accuracy)[0.860,68], d(loss on real and fake)[1.450,1.452], d(acc on real and fake)[4.460,4.450], g(loss)[0.207]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >243, c(loss and accuracy)[0.860,68], d(loss on real and fake)[1.451,1.454], d(acc on real and fake)[4.454,4.444], g(loss)[0.206]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >244, c(loss and accuracy)[0.861,68], d(loss on real and fake)[1.453,1.455], d(acc on real and fake)[4.444,4.434], g(loss)[0.206]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >245, c(loss and accuracy)[0.861,68], d(loss on real and fake)[1.454,1.456], d(acc on real and fake)[4.436,4.427], g(loss)[0.205]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >246, c(loss and accuracy)[0.862,68], d(loss on real and fake)[1.455,1.458], d(acc on real and fake)[4.426,4.417], g(loss)[0.205]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >247, c(loss and accuracy)[0.862,68], d(loss on real and fake)[1.457,1.459], d(acc on real and fake)[4.412,4.403], g(loss)[0.204]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >248, c(loss and accuracy)[0.863,67], d(loss on real and fake)[1.458,1.460], d(acc on real and fake)[4.410,4.401], g(loss)[0.204]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >249, c(loss and accuracy)[0.863,67], d(loss on real and fake)[1.459,1.461], d(acc on real and fake)[4.404,4.396], g(loss)[0.203]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >250, c(loss and accuracy)[0.864,67], d(loss on real and fake)[1.460,1.463], d(acc on real and fake)[4.399,4.390], g(loss)[0.203]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >251, c(loss and accuracy)[0.864,67], d(loss on real and fake)[1.462,1.464], d(acc on real and fake)[4.391,4.382], g(loss)[0.202]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >252, c(loss and accuracy)[0.865,67], d(loss on real and fake)[1.463,1.465], d(acc on real and fake)[4.386,4.377], g(loss)[0.202]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >253, c(loss and accuracy)[0.865,67], d(loss on real and fake)[1.464,1.466], d(acc on real and fake)[4.372,4.364], g(loss)[0.201]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >254, c(loss and accuracy)[0.865,67], d(loss on real and fake)[1.465,1.468], d(acc on real and fake)[4.367,4.358], g(loss)[0.201]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >255, c(loss and accuracy)[0.866,67], d(loss on real and fake)[1.467,1.469], d(acc on real and fake)[4.354,4.345], g(loss)[0.200]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >256, c(loss and accuracy)[0.866,67], d(loss on real and fake)[1.468,1.470], d(acc on real and fake)[4.342,4.334], g(loss)[0.200]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >257, c(loss and accuracy)[0.867,66], d(loss on real and fake)[1.469,1.471], d(acc on real and fake)[4.347,4.339], g(loss)[0.199]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >258, c(loss and accuracy)[0.867,66], d(loss on real and fake)[1.470,1.472], d(acc on real and fake)[4.336,4.328], g(loss)[0.199]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >259, c(loss and accuracy)[0.868,66], d(loss on real and fake)[1.471,1.473], d(acc on real and fake)[4.331,4.322], g(loss)[0.198]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >260, c(loss and accuracy)[0.868,66], d(loss on real and fake)[1.472,1.474], d(acc on real and fake)[4.324,4.315], g(loss)[0.198]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >261, c(loss and accuracy)[0.869,66], d(loss on real and fake)[1.473,1.476], d(acc on real and fake)[4.322,4.314], g(loss)[0.198]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >262, c(loss and accuracy)[0.869,66], d(loss on real and fake)[1.475,1.477], d(acc on real and fake)[4.312,4.303], g(loss)[0.197]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >263, c(loss and accuracy)[0.869,66], d(loss on real and fake)[1.476,1.478], d(acc on real and fake)[4.303,4.295], g(loss)[0.197]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >264, c(loss and accuracy)[0.870,66], d(loss on real and fake)[1.477,1.479], d(acc on real and fake)[4.298,4.290], g(loss)[0.196]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >265, c(loss and accuracy)[0.870,66], d(loss on real and fake)[1.478,1.480], d(acc on real and fake)[4.293,4.285], g(loss)[0.196]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >266, c(loss and accuracy)[0.871,66], d(loss on real and fake)[1.479,1.481], d(acc on real and fake)[4.286,4.278], g(loss)[0.195]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >267, c(loss and accuracy)[0.871,65], d(loss on real and fake)[1.480,1.482], d(acc on real and fake)[4.276,4.268], g(loss)[0.195]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >268, c(loss and accuracy)[0.871,65], d(loss on real and fake)[1.481,1.484], d(acc on real and fake)[4.265,4.257], g(loss)[0.194]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >269, c(loss and accuracy)[0.872,65], d(loss on real and fake)[1.483,1.485], d(acc on real and fake)[4.268,4.260], g(loss)[0.194]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >270, c(loss and accuracy)[0.872,65], d(loss on real and fake)[1.484,1.486], d(acc on real and fake)[4.262,4.254], g(loss)[0.194]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >271, c(loss and accuracy)[0.873,65], d(loss on real and fake)[1.485,1.487], d(acc on real and fake)[4.255,4.247], g(loss)[0.193]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >272, c(loss and accuracy)[0.873,65], d(loss on real and fake)[1.486,1.488], d(acc on real and fake)[4.252,4.244], g(loss)[0.193]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >273, c(loss and accuracy)[0.873,65], d(loss on real and fake)[1.487,1.489], d(acc on real and fake)[4.244,4.236], g(loss)[0.192]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >274, c(loss and accuracy)[0.874,65], d(loss on real and fake)[1.488,1.490], d(acc on real and fake)[4.236,4.228], g(loss)[0.192]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >275, c(loss and accuracy)[0.875,65], d(loss on real and fake)[1.489,1.491], d(acc on real and fake)[4.230,4.222], g(loss)[0.191]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >276, c(loss and accuracy)[0.875,65], d(loss on real and fake)[1.490,1.492], d(acc on real and fake)[4.236,4.228], g(loss)[0.191]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# ...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >398, c(loss and accuracy)[0.883,63], d(loss on real and fake)[1.595,1.597], d(acc on real and fake)[3.785,3.780], g(loss)[0.154]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >399, c(loss and accuracy)[0.884,63], d(loss on real and fake)[1.596,1.597], d(acc on real and fake)[3.780,3.776], g(loss)[0.154]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >400, c(loss and accuracy)[0.884,63], d(loss on real and fake)[1.596,1.598], d(acc on real and fake)[3.778,3.774], g(loss)[0.154]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Classifier Accuracy: 73.952%
# >Saved:  g_model_0400.h5 and c_model_0400.h5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >401, c(loss and accuracy)[0.839,74], d(loss on real and fake)[1.597,1.599], d(acc on real and fake)[3.775,3.771], g(loss)[0.154]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >402, c(loss and accuracy)[0.840,74], d(loss on real and fake)[1.598,1.599], d(acc on real and fake)[3.770,3.765], g(loss)[0.153]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >403, c(loss and accuracy)[0.840,74], d(loss on real and fake)[1.599,1.600], d(acc on real and fake)[3.765,3.761], g(loss)[0.153]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >404, c(loss and accuracy)[0.841,73], d(loss on real and fake)[1.599,1.601], d(acc on real and fake)[3.762,3.757], g(loss)[0.153]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >405, c(loss and accuracy)[0.841,73], d(loss on real and fake)[1.600,1.601], d(acc on real and fake)[3.764,3.759], g(loss)[0.153]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >406, c(loss and accuracy)[0.842,73], d(loss on real and fake)[1.601,1.602], d(acc on real and fake)[3.758,3.754], g(loss)[0.153]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >407, c(loss and accuracy)[0.842,73], d(loss on real and fake)[1.601,1.603], d(acc on real and fake)[3.756,3.752], g(loss)[0.152]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >408, c(loss and accuracy)[0.843,73], d(loss on real and fake)[1.602,1.604], d(acc on real and fake)[3.755,3.750], g(loss)[0.152]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >409, c(loss and accuracy)[0.843,73], d(loss on real and fake)[1.603,1.604], d(acc on real and fake)[3.752,3.747], g(loss)[0.152]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >410, c(loss and accuracy)[0.844,73], d(loss on real and fake)[1.603,1.605], d(acc on real and fake)[3.747,3.743], g(loss)[0.152]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >411, c(loss and accuracy)[0.844,72], d(loss on real and fake)[1.604,1.605], d(acc on real and fake)[3.744,3.740], g(loss)[0.151]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >412, c(loss and accuracy)[0.845,72], d(loss on real and fake)[1.605,1.606], d(acc on real and fake)[3.747,3.743], g(loss)[0.151]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >413, c(loss and accuracy)[0.845,72], d(loss on real and fake)[1.605,1.607], d(acc on real and fake)[3.742,3.737], g(loss)[0.151]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >414, c(loss and accuracy)[0.846,72], d(loss on real and fake)[1.606,1.607], d(acc on real and fake)[3.735,3.731], g(loss)[0.151]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >415, c(loss and accuracy)[0.846,72], d(loss on real and fake)[1.607,1.608], d(acc on real and fake)[3.730,3.725], g(loss)[0.151]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >416, c(loss and accuracy)[0.847,72], d(loss on real and fake)[1.607,1.609], d(acc on real and fake)[3.734,3.730], g(loss)[0.150]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >417, c(loss and accuracy)[0.847,71], d(loss on real and fake)[1.608,1.609], d(acc on real and fake)[3.732,3.728], g(loss)[0.150]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >418, c(loss and accuracy)[0.848,71], d(loss on real and fake)[1.609,1.610], d(acc on real and fake)[3.733,3.728], g(loss)[0.150]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >419, c(loss and accuracy)[0.848,71], d(loss on real and fake)[1.609,1.611], d(acc on real and fake)[3.734,3.729], g(loss)[0.150]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >420, c(loss and accuracy)[0.848,71], d(loss on real and fake)[1.610,1.611], d(acc on real and fake)[3.726,3.721], g(loss)[0.150]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >421, c(loss and accuracy)[0.849,71], d(loss on real and fake)[1.611,1.612], d(acc on real and fake)[3.722,3.717], g(loss)[0.149]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >422, c(loss and accuracy)[0.850,71], d(loss on real and fake)[1.611,1.613], d(acc on real and fake)[3.718,3.713], g(loss)[0.149]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >423, c(loss and accuracy)[0.850,71], d(loss on real and fake)[1.612,1.613], d(acc on real and fake)[3.711,3.707], g(loss)[0.149]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >424, c(loss and accuracy)[0.851,71], d(loss on real and fake)[1.612,1.614], d(acc on real and fake)[3.708,3.704], g(loss)[0.149]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >425, c(loss and accuracy)[0.851,70], d(loss on real and fake)[1.613,1.614], d(acc on real and fake)[3.713,3.708], g(loss)[0.149]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >426, c(loss and accuracy)[0.851,70], d(loss on real and fake)[1.614,1.615], d(acc on real and fake)[3.712,3.708], g(loss)[0.148]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >427, c(loss and accuracy)[0.852,70], d(loss on real and fake)[1.614,1.616], d(acc on real and fake)[3.708,3.704], g(loss)[0.148]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >428, c(loss and accuracy)[0.852,70], d(loss on real and fake)[1.615,1.616], d(acc on real and fake)[3.702,3.697], g(loss)[0.148]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >429, c(loss and accuracy)[0.853,70], d(loss on real and fake)[1.616,1.617], d(acc on real and fake)[3.698,3.693], g(loss)[0.148]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >430, c(loss and accuracy)[0.853,70], d(loss on real and fake)[1.616,1.618], d(acc on real and fake)[3.700,3.695], g(loss)[0.148]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >431, c(loss and accuracy)[0.854,70], d(loss on real and fake)[1.617,1.618], d(acc on real and fake)[3.695,3.690], g(loss)[0.147]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >432, c(loss and accuracy)[0.854,70], d(loss on real and fake)[1.617,1.619], d(acc on real and fake)[3.691,3.686], g(loss)[0.147]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >433, c(loss and accuracy)[0.855,70], d(loss on real and fake)[1.618,1.619], d(acc on real and fake)[3.687,3.682], g(loss)[0.147]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >434, c(loss and accuracy)[0.855,69], d(loss on real and fake)[1.619,1.620], d(acc on real and fake)[3.684,3.680], g(loss)[0.147]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >435, c(loss and accuracy)[0.856,69], d(loss on real and fake)[1.619,1.621], d(acc on real and fake)[3.681,3.677], g(loss)[0.147]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >436, c(loss and accuracy)[0.856,69], d(loss on real and fake)[1.620,1.621], d(acc on real and fake)[3.680,3.675], g(loss)[0.147]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >437, c(loss and accuracy)[0.856,69], d(loss on real and fake)[1.620,1.622], d(acc on real and fake)[3.678,3.674], g(loss)[0.146]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >438, c(loss and accuracy)[0.857,69], d(loss on real and fake)[1.621,1.622], d(acc on real and fake)[3.678,3.674], g(loss)[0.146]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >439, c(loss and accuracy)[0.857,69], d(loss on real and fake)[1.621,1.623], d(acc on real and fake)[3.676,3.672], g(loss)[0.146]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >440, c(loss and accuracy)[0.858,69], d(loss on real and fake)[1.622,1.623], d(acc on real and fake)[3.672,3.668], g(loss)[0.146]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >441, c(loss and accuracy)[0.858,69], d(loss on real and fake)[1.623,1.624], d(acc on real and fake)[3.669,3.664], g(loss)[0.146]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >442, c(loss and accuracy)[0.859,68], d(loss on real and fake)[1.623,1.625], d(acc on real and fake)[3.663,3.658], g(loss)[0.145]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >443, c(loss and accuracy)[0.859,68], d(loss on real and fake)[1.624,1.625], d(acc on real and fake)[3.656,3.652], g(loss)[0.145]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >444, c(loss and accuracy)[0.860,68], d(loss on real and fake)[1.624,1.626], d(acc on real and fake)[3.653,3.649], g(loss)[0.145]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >445, c(loss and accuracy)[0.860,68], d(loss on real and fake)[1.625,1.626], d(acc on real and fake)[3.650,3.646], g(loss)[0.145]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >446, c(loss and accuracy)[0.861,68], d(loss on real and fake)[1.626,1.627], d(acc on real and fake)[3.649,3.645], g(loss)[0.145]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >447, c(loss and accuracy)[0.861,68], d(loss on real and fake)[1.626,1.627], d(acc on real and fake)[3.646,3.642], g(loss)[0.145]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >448, c(loss and accuracy)[0.862,68], d(loss on real and fake)[1.627,1.628], d(acc on real and fake)[3.645,3.641], g(loss)[0.144]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >449, c(loss and accuracy)[0.862,68], d(loss on real and fake)[1.627,1.629], d(acc on real and fake)[3.642,3.638], g(loss)[0.144]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >450, c(loss and accuracy)[0.862,68], d(loss on real and fake)[1.628,1.629], d(acc on real and fake)[3.638,3.634], g(loss)[0.144]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >451, c(loss and accuracy)[0.863,67], d(loss on real and fake)[1.628,1.630], d(acc on real and fake)[3.633,3.629], g(loss)[0.144]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >452, c(loss and accuracy)[0.863,67], d(loss on real and fake)[1.629,1.630], d(acc on real and fake)[3.630,3.626], g(loss)[0.144]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >453, c(loss and accuracy)[0.864,67], d(loss on real and fake)[1.629,1.631], d(acc on real and fake)[3.627,3.623], g(loss)[0.143]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >454, c(loss and accuracy)[0.864,67], d(loss on real and fake)[1.630,1.631], d(acc on real and fake)[3.627,3.623], g(loss)[0.143]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >455, c(loss and accuracy)[0.865,67], d(loss on real and fake)[1.631,1.632], d(acc on real and fake)[3.626,3.622], g(loss)[0.143]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >456, c(loss and accuracy)[0.865,67], d(loss on real and fake)[1.631,1.633], d(acc on real and fake)[3.620,3.616], g(loss)[0.143]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >457, c(loss and accuracy)[0.866,67], d(loss on real and fake)[1.632,1.633], d(acc on real and fake)[3.616,3.612], g(loss)[0.143]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >458, c(loss and accuracy)[0.866,67], d(loss on real and fake)[1.632,1.634], d(acc on real and fake)[3.614,3.610], g(loss)[0.143]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >459, c(loss and accuracy)[0.867,67], d(loss on real and fake)[1.633,1.634], d(acc on real and fake)[3.613,3.609], g(loss)[0.142]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >460, c(loss and accuracy)[0.867,66], d(loss on real and fake)[1.634,1.635], d(acc on real and fake)[3.609,3.605], g(loss)[0.142]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >461, c(loss and accuracy)[0.867,66], d(loss on real and fake)[1.634,1.635], d(acc on real and fake)[3.605,3.601], g(loss)[0.142]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >462, c(loss and accuracy)[0.868,66], d(loss on real and fake)[1.635,1.636], d(acc on real and fake)[3.603,3.600], g(loss)[0.142]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >463, c(loss and accuracy)[0.868,66], d(loss on real and fake)[1.635,1.637], d(acc on real and fake)[3.603,3.599], g(loss)[0.142]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >464, c(loss and accuracy)[0.869,66], d(loss on real and fake)[1.636,1.637], d(acc on real and fake)[3.599,3.595], g(loss)[0.142]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >465, c(loss and accuracy)[0.869,66], d(loss on real and fake)[1.636,1.638], d(acc on real and fake)[3.595,3.591], g(loss)[0.141]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >466, c(loss and accuracy)[0.870,66], d(loss on real and fake)[1.637,1.638], d(acc on real and fake)[3.592,3.588], g(loss)[0.141]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >467, c(loss and accuracy)[0.870,66], d(loss on real and fake)[1.637,1.639], d(acc on real and fake)[3.599,3.595], g(loss)[0.141]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >468, c(loss and accuracy)[0.871,66], d(loss on real and fake)[1.638,1.639], d(acc on real and fake)[3.598,3.594], g(loss)[0.141]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >469, c(loss and accuracy)[0.871,66], d(loss on real and fake)[1.639,1.640], d(acc on real and fake)[3.594,3.591], g(loss)[0.141]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >470, c(loss and accuracy)[0.872,65], d(loss on real and fake)[1.639,1.640], d(acc on real and fake)[3.592,3.588], g(loss)[0.141]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >471, c(loss and accuracy)[0.872,65], d(loss on real and fake)[1.640,1.641], d(acc on real and fake)[3.591,3.587], g(loss)[0.140]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >472, c(loss and accuracy)[0.872,65], d(loss on real and fake)[1.640,1.642], d(acc on real and fake)[3.585,3.582], g(loss)[0.140]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >473, c(loss and accuracy)[0.873,65], d(loss on real and fake)[1.641,1.642], d(acc on real and fake)[3.584,3.580], g(loss)[0.140]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >474, c(loss and accuracy)[0.873,65], d(loss on real and fake)[1.641,1.643], d(acc on real and fake)[3.583,3.579], g(loss)[0.140]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >475, c(loss and accuracy)[0.874,65], d(loss on real and fake)[1.642,1.643], d(acc on real and fake)[3.581,3.577], g(loss)[0.140]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >476, c(loss and accuracy)[0.874,65], d(loss on real and fake)[1.642,1.644], d(acc on real and fake)[3.574,3.570], g(loss)[0.140]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >477, c(loss and accuracy)[0.875,65], d(loss on real and fake)[1.643,1.644], d(acc on real and fake)[3.569,3.565], g(loss)[0.139]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >478, c(loss and accuracy)[0.875,65], d(loss on real and fake)[1.643,1.645], d(acc on real and fake)[3.566,3.563], g(loss)[0.139]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# >479, c(loss and accuracy)[0.875,65], d(loss on real and fake)[1.644,1.645], d(acc on real and fake)[3.565,3.562], g(loss)[0.139]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >480, c(loss and accuracy)[0.876,64], d(loss on real and fake)[1.645,1.646], d(acc on real and fake)[3.565,3.561], g(loss)[0.139]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >481, c(loss and accuracy)[0.876,64], d(loss on real and fake)[1.645,1.646], d(acc on real and fake)[3.562,3.558], g(loss)[0.139]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >482, c(loss and accuracy)[0.877,64], d(loss on real and fake)[1.646,1.647], d(acc on real and fake)[3.561,3.557], g(loss)[0.139]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >483, c(loss and accuracy)[0.877,64], d(loss on real and fake)[1.646,1.647], d(acc on real and fake)[3.559,3.555], g(loss)[0.138]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >484, c(loss and accuracy)[0.877,64], d(loss on real and fake)[1.647,1.648], d(acc on real and fake)[3.560,3.557], g(loss)[0.138]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >485, c(loss and accuracy)[0.878,64], d(loss on real and fake)[1.647,1.648], d(acc on real and fake)[3.564,3.561], g(loss)[0.138]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >486, c(loss and accuracy)[0.878,64], d(loss on real and fake)[1.648,1.649], d(acc on real and fake)[3.566,3.563], g(loss)[0.138]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >487, c(loss and accuracy)[0.879,64], d(loss on real and fake)[1.648,1.649], d(acc on real and fake)[3.564,3.561], g(loss)[0.138]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >488, c(loss and accuracy)[0.879,64], d(loss on real and fake)[1.649,1.650], d(acc on real and fake)[3.563,3.559], g(loss)[0.138]

# %%
test_loss, test_accuracy = c_model.evaluate(X_test, y_test, verbose=0)
print('Test Accuracy for multiclass classification model: %.3f%%' % (test_accuracy * 100))
# Out:
# Test Accuracy for multiclass classification model: 73.607%

# %% [markdown]
# It looks like the multiclass discriminator model performed terribly on the test set. We will now test our binary discriminator that tests our model's ability to distinguish real from fake.

# %%
#Since everything in our X_test and y_test are "real" samples, 
#let's add some fake samples so there is a 50/50 split between real and fake
fake_embeddings, classification = generate_fake_samples(g_model, latent_dim, len(X_test))
# Out:
# 255/255 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step

# %%
X_test_with_fakes = np.concatenate((X_test, fake_embeddings), axis = 0)

# %%
y_test_with_fakes = np.concatenate((np.ones(len(X_test)), classification.flatten()), axis = 0)

# %%
# Generate shuffled indices
indices = tf.range(start=0, limit=tf.shape(X_test_with_fakes)[0], dtype=tf.int32)
shuffled_indices = tf.random.shuffle(indices)

# Reorder both X and y using the shuffled indices
X_test_with_fakes_shuffled = tf.gather(X_test_with_fakes, shuffled_indices)
y_test_with_fakes_shuffled = tf.gather(y_test_with_fakes, shuffled_indices)

# %%
test_loss, test_accuracy = d_model.evaluate(X_test_with_fakes_shuffled, y_test_with_fakes_shuffled, verbose=0)
print('Test Accuracy for binary discriminator: %.3f%%' % (test_accuracy * 100))
# Out:
# Test Accuracy for binary discriminator: 0.055%

# %% [markdown]
# It looks like the binary discriminator didn't perform anywhere above the baseline.

# %% [markdown]
# ### Grid Search with Latent Dimensions

# %%
latent_dims = [100, 200, 300 , 400, 500]

for latent_dim in latent_dims:
    train_script(latent_dim)
# Out:
# Latent dimensions: 100
# -------------
# (999, 768) (999,)
# n_epochs=2, n_batch=100, 1/2=50, b/e=244, steps=488
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# >1, c(loss and accuracy)[1.165,34], d(loss on real and fake)[0.513,0.759], d(acc on real and fake)[80.000,45.500], g(loss)[0.487]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >2, c(loss and accuracy)[1.181,32], d(loss on real and fake)[0.677,0.764], d(acc on real and fake)[56.667,45.250], g(loss)[0.468]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >3, c(loss and accuracy)[1.195,32], d(loss on real and fake)[0.722,0.777], d(acc on real and fake)[52.800,45.167], g(loss)[0.466]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >4, c(loss and accuracy)[1.179,33], d(loss on real and fake)[0.739,0.787], d(acc on real and fake)[50.286,45.000], g(loss)[0.451]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >5, c(loss and accuracy)[1.182,32], d(loss on real and fake)[0.755,0.797], d(acc on real and fake)[49.222,44.700], g(loss)[0.444]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >6, c(loss and accuracy)[1.181,32], d(loss on real and fake)[0.767,0.807], d(acc on real and fake)[48.364,44.417], g(loss)[0.434]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >7, c(loss and accuracy)[1.183,32], d(loss on real and fake)[0.783,0.815], d(acc on real and fake)[47.308,44.143], g(loss)[0.423]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >8, c(loss and accuracy)[1.191,31], d(loss on real and fake)[0.793,0.823], d(acc on real and fake)[46.733,43.938], g(loss)[0.412]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >9, c(loss and accuracy)[1.186,32], d(loss on real and fake)[0.802,0.830], d(acc on real and fake)[46.294,43.889], g(loss)[0.401]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >10, c(loss and accuracy)[1.185,32], d(loss on real and fake)[0.814,0.846], d(acc on real and fake)[45.842,43.550], g(loss)[0.390]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >11, c(loss and accuracy)[1.178,32], d(loss on real and fake)[0.830,0.859], d(acc on real and fake)[45.190,43.182], g(loss)[0.382]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >12, c(loss and accuracy)[1.172,33], d(loss on real and fake)[0.843,0.869], d(acc on real and fake)[45.217,43.333], g(loss)[0.374]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >13, c(loss and accuracy)[1.173,33], d(loss on real and fake)[0.854,0.881], d(acc on real and fake)[44.920,43.192], g(loss)[0.365]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >14, c(loss and accuracy)[1.173,33], d(loss on real and fake)[0.866,0.891], d(acc on real and fake)[44.704,43.143], g(loss)[0.357]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >15, c(loss and accuracy)[1.178,33], d(loss on real and fake)[0.877,0.904], d(acc on real and fake)[44.621,43.133], g(loss)[0.349]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >16, c(loss and accuracy)[1.175,33], d(loss on real and fake)[0.890,0.916], d(acc on real and fake)[44.548,43.156], g(loss)[0.341]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >17, c(loss and accuracy)[1.178,33], d(loss on real and fake)[0.903,0.928], d(acc on real and fake)[44.424,43.118], g(loss)[0.333]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >18, c(loss and accuracy)[1.176,33], d(loss on real and fake)[0.915,0.938], d(acc on real and fake)[44.257,43.028], g(loss)[0.326]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >19, c(loss and accuracy)[1.175,33], d(loss on real and fake)[0.926,0.949], d(acc on real and fake)[44.135,42.974], g(loss)[0.318]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >20, c(loss and accuracy)[1.180,33], d(loss on real and fake)[0.937,0.960], d(acc on real and fake)[43.974,42.875], g(loss)[0.312]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >21, c(loss and accuracy)[1.177,33], d(loss on real and fake)[0.949,0.971], d(acc on real and fake)[43.902,42.857], g(loss)[0.306]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >22, c(loss and accuracy)[1.178,33], d(loss on real and fake)[0.960,0.981], d(acc on real and fake)[43.884,42.886], g(loss)[0.300]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >23, c(loss and accuracy)[1.178,33], d(loss on real and fake)[0.971,0.993], d(acc on real and fake)[43.711,42.761], g(loss)[0.294]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >24, c(loss and accuracy)[1.178,33], d(loss on real and fake)[0.983,1.005], d(acc on real and fake)[43.532,42.625], g(loss)[0.288]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >25, c(loss and accuracy)[1.179,33], d(loss on real and fake)[0.995,1.017], d(acc on real and fake)[43.429,42.560], g(loss)[0.282]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >26, c(loss and accuracy)[1.177,33], d(loss on real and fake)[1.008,1.028], d(acc on real and fake)[43.275,42.442], g(loss)[0.276]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >27, c(loss and accuracy)[1.174,33], d(loss on real and fake)[1.018,1.038], d(acc on real and fake)[43.226,42.426], g(loss)[0.272]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >28, c(loss and accuracy)[1.173,33], d(loss on real and fake)[1.028,1.048], d(acc on real and fake)[43.255,42.482], g(loss)[0.266]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# >29, c(loss and accuracy)[1.172,33], d(loss on real and fake)[1.038,1.058], d(acc on real and fake)[43.246,42.500], g(loss)[0.261]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >30, c(loss and accuracy)[1.175,33], d(loss on real and fake)[1.049,1.069], d(acc on real and fake)[43.186,42.467], g(loss)[0.257]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >31, c(loss and accuracy)[1.175,33], d(loss on real and fake)[1.059,1.079], d(acc on real and fake)[43.098,42.403], g(loss)[0.252]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >32, c(loss and accuracy)[1.176,33], d(loss on real and fake)[1.070,1.090], d(acc on real and fake)[42.937,42.266], g(loss)[0.247]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >33, c(loss and accuracy)[1.176,33], d(loss on real and fake)[1.080,1.100], d(acc on real and fake)[42.923,42.273], g(loss)[0.243]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >34, c(loss and accuracy)[1.174,33], d(loss on real and fake)[1.091,1.111], d(acc on real and fake)[42.881,42.250], g(loss)[0.239]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >35, c(loss and accuracy)[1.174,33], d(loss on real and fake)[1.101,1.121], d(acc on real and fake)[42.899,42.286], g(loss)[0.235]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >36, c(loss and accuracy)[1.175,33], d(loss on real and fake)[1.112,1.132], d(acc on real and fake)[42.817,42.222], g(loss)[0.231]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >37, c(loss and accuracy)[1.176,33], d(loss on real and fake)[1.124,1.143], d(acc on real and fake)[42.726,42.149], g(loss)[0.227]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >38, c(loss and accuracy)[1.176,33], d(loss on real and fake)[1.135,1.154], d(acc on real and fake)[42.720,42.158], g(loss)[0.223]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# >39, c(loss and accuracy)[1.176,33], d(loss on real and fake)[1.145,1.164], d(acc on real and fake)[42.662,42.115], g(loss)[0.220]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >40, c(loss and accuracy)[1.176,33], d(loss on real and fake)[1.155,1.174], d(acc on real and fake)[42.633,42.100], g(loss)[0.216]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >41, c(loss and accuracy)[1.176,33], d(loss on real and fake)[1.166,1.185], d(acc on real and fake)[42.543,42.024], g(loss)[0.213]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >42, c(loss and accuracy)[1.176,33], d(loss on real and fake)[1.176,1.195], d(acc on real and fake)[42.530,42.024], g(loss)[0.210]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >43, c(loss and accuracy)[1.177,33], d(loss on real and fake)[1.187,1.205], d(acc on real and fake)[42.435,41.942], g(loss)[0.207]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >44, c(loss and accuracy)[1.176,33], d(loss on real and fake)[1.197,1.215], d(acc on real and fake)[42.448,41.966], g(loss)[0.204]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >45, c(loss and accuracy)[1.176,33], d(loss on real and fake)[1.207,1.224], d(acc on real and fake)[42.382,41.911], g(loss)[0.201]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >46, c(loss and accuracy)[1.176,33], d(loss on real and fake)[1.216,1.234], d(acc on real and fake)[42.330,41.870], g(loss)[0.198]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >47, c(loss and accuracy)[1.177,33], d(loss on real and fake)[1.226,1.243], d(acc on real and fake)[42.366,41.915], g(loss)[0.195]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >48, c(loss and accuracy)[1.177,33], d(loss on real and fake)[1.236,1.253], d(acc on real and fake)[42.284,41.844], g(loss)[0.192]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >49, c(loss and accuracy)[1.177,33], d(loss on real and fake)[1.245,1.261], d(acc on real and fake)[42.196,41.765], g(loss)[0.190]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >50, c(loss and accuracy)[1.177,33], d(loss on real and fake)[1.254,1.272], d(acc on real and fake)[42.141,41.720], g(loss)[0.187]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >51, c(loss and accuracy)[1.176,33], d(loss on real and fake)[1.264,1.280], d(acc on real and fake)[42.149,41.735], g(loss)[0.185]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >52, c(loss and accuracy)[1.176,33], d(loss on real and fake)[1.273,1.288], d(acc on real and fake)[42.117,41.712], g(loss)[0.182]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >53, c(loss and accuracy)[1.176,33], d(loss on real and fake)[1.281,1.297], d(acc on real and fake)[42.095,41.698], g(loss)[0.180]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >54, c(loss and accuracy)[1.176,33], d(loss on real and fake)[1.290,1.306], d(acc on real and fake)[42.056,41.667], g(loss)[0.177]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >55, c(loss and accuracy)[1.176,33], d(loss on real and fake)[1.299,1.315], d(acc on real and fake)[42.037,41.655], g(loss)[0.175]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >56, c(loss and accuracy)[1.176,33], d(loss on real and fake)[1.308,1.324], d(acc on real and fake)[42.036,41.661], g(loss)[0.173]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >57, c(loss and accuracy)[1.177,33], d(loss on real and fake)[1.317,1.332], d(acc on real and fake)[42.027,41.658], g(loss)[0.171]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >58, c(loss and accuracy)[1.176,33], d(loss on real and fake)[1.325,1.341], d(acc on real and fake)[42.026,41.664], g(loss)[0.169]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >59, c(loss and accuracy)[1.176,33], d(loss on real and fake)[1.334,1.350], d(acc on real and fake)[42.000,41.644], g(loss)[0.166]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >60, c(loss and accuracy)[1.176,33], d(loss on real and fake)[1.343,1.358], d(acc on real and fake)[42.034,41.683], g(loss)[0.164]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >61, c(loss and accuracy)[1.175,33], d(loss on real and fake)[1.351,1.366], d(acc on real and fake)[42.066,41.721], g(loss)[0.162]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >62, c(loss and accuracy)[1.174,33], d(loss on real and fake)[1.359,1.375], d(acc on real and fake)[42.024,41.685], g(loss)[0.161]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >63, c(loss and accuracy)[1.174,33], d(loss on real and fake)[1.367,1.382], d(acc on real and fake)[42.032,41.698], g(loss)[0.159]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >64, c(loss and accuracy)[1.173,33], d(loss on real and fake)[1.375,1.390], d(acc on real and fake)[42.016,41.688], g(loss)[0.157]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >65, c(loss and accuracy)[1.174,33], d(loss on real and fake)[1.383,1.399], d(acc on real and fake)[42.039,41.715], g(loss)[0.155]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >66, c(loss and accuracy)[1.173,33], d(loss on real and fake)[1.391,1.406], d(acc on real and fake)[42.053,41.735], g(loss)[0.153]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >67, c(loss and accuracy)[1.173,33], d(loss on real and fake)[1.399,1.413], d(acc on real and fake)[42.075,41.761], g(loss)[0.152]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >68, c(loss and accuracy)[1.172,33], d(loss on real and fake)[1.407,1.421], d(acc on real and fake)[42.074,41.765], g(loss)[0.150]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >69, c(loss and accuracy)[1.173,33], d(loss on real and fake)[1.415,1.429], d(acc on real and fake)[42.051,41.746], g(loss)[0.148]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >70, c(loss and accuracy)[1.173,33], d(loss on real and fake)[1.422,1.436], d(acc on real and fake)[42.036,41.736], g(loss)[0.147]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >71, c(loss and accuracy)[1.172,33], d(loss on real and fake)[1.429,1.444], d(acc on real and fake)[41.993,41.697], g(loss)[0.145]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >72, c(loss and accuracy)[1.172,33], d(loss on real and fake)[1.437,1.451], d(acc on real and fake)[42.014,41.722], g(loss)[0.144]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >73, c(loss and accuracy)[1.172,33], d(loss on real and fake)[1.444,1.458], d(acc on real and fake)[42.021,41.733], g(loss)[0.142]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >74, c(loss and accuracy)[1.172,33], d(loss on real and fake)[1.452,1.466], d(acc on real and fake)[41.980,41.696], g(loss)[0.141]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >75, c(loss and accuracy)[1.171,33], d(loss on real and fake)[1.460,1.474], d(acc on real and fake)[42.013,41.733], g(loss)[0.139]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >76, c(loss and accuracy)[1.173,33], d(loss on real and fake)[1.467,1.481], d(acc on real and fake)[41.980,41.704], g(loss)[0.138]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >77, c(loss and accuracy)[1.173,33], d(loss on real and fake)[1.475,1.488], d(acc on real and fake)[42.000,41.727], g(loss)[0.137]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >78, c(loss and accuracy)[1.173,33], d(loss on real and fake)[1.482,1.495], d(acc on real and fake)[41.987,41.718], g(loss)[0.135]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >79, c(loss and accuracy)[1.174,33], d(loss on real and fake)[1.489,1.502], d(acc on real and fake)[41.987,41.722], g(loss)[0.134]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >80, c(loss and accuracy)[1.173,33], d(loss on real and fake)[1.496,1.509], d(acc on real and fake)[41.994,41.731], g(loss)[0.133]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >81, c(loss and accuracy)[1.174,33], d(loss on real and fake)[1.503,1.516], d(acc on real and fake)[41.981,41.722], g(loss)[0.132]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >82, c(loss and accuracy)[1.175,33], d(loss on real and fake)[1.509,1.523], d(acc on real and fake)[41.982,41.726], g(loss)[0.130]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >83, c(loss and accuracy)[1.175,33], d(loss on real and fake)[1.516,1.529], d(acc on real and fake)[41.927,41.675], g(loss)[0.129]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >84, c(loss and accuracy)[1.175,33], d(loss on real and fake)[1.523,1.536], d(acc on real and fake)[41.886,41.637], g(loss)[0.128]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >85, c(loss and accuracy)[1.176,33], d(loss on real and fake)[1.530,1.543], d(acc on real and fake)[41.852,41.606], g(loss)[0.127]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >86, c(loss and accuracy)[1.176,33], d(loss on real and fake)[1.537,1.549], d(acc on real and fake)[41.830,41.587], g(loss)[0.126]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >87, c(loss and accuracy)[1.175,33], d(loss on real and fake)[1.543,1.555], d(acc on real and fake)[41.815,41.575], g(loss)[0.124]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >88, c(loss and accuracy)[1.175,33], d(loss on real and fake)[1.549,1.562], d(acc on real and fake)[41.834,41.597], g(loss)[0.123]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >89, c(loss and accuracy)[1.174,33], d(loss on real and fake)[1.555,1.568], d(acc on real and fake)[41.847,41.612], g(loss)[0.122]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >90, c(loss and accuracy)[1.174,33], d(loss on real and fake)[1.562,1.574], d(acc on real and fake)[41.838,41.606], g(loss)[0.121]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >91, c(loss and accuracy)[1.173,33], d(loss on real and fake)[1.569,1.581], d(acc on real and fake)[41.823,41.593], g(loss)[0.120]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >92, c(loss and accuracy)[1.174,33], d(loss on real and fake)[1.575,1.587], d(acc on real and fake)[41.803,41.576], g(loss)[0.119]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >93, c(loss and accuracy)[1.174,33], d(loss on real and fake)[1.581,1.593], d(acc on real and fake)[41.789,41.565], g(loss)[0.118]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >94, c(loss and accuracy)[1.174,33], d(loss on real and fake)[1.587,1.599], d(acc on real and fake)[41.786,41.564], g(loss)[0.117]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >95, c(loss and accuracy)[1.174,33], d(loss on real and fake)[1.593,1.605], d(acc on real and fake)[41.783,41.563], g(loss)[0.116]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >96, c(loss and accuracy)[1.174,33], d(loss on real and fake)[1.599,1.610], d(acc on real and fake)[41.780,41.563], g(loss)[0.115]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >97, c(loss and accuracy)[1.174,33], d(loss on real and fake)[1.605,1.617], d(acc on real and fake)[41.782,41.567], g(loss)[0.114]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >98, c(loss and accuracy)[1.175,33], d(loss on real and fake)[1.611,1.622], d(acc on real and fake)[41.790,41.577], g(loss)[0.113]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >99, c(loss and accuracy)[1.174,33], d(loss on real and fake)[1.617,1.628], d(acc on real and fake)[41.792,41.581], g(loss)[0.112]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >100, c(loss and accuracy)[1.174,33], d(loss on real and fake)[1.623,1.634], d(acc on real and fake)[41.754,41.545], g(loss)[0.112]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Classifier Accuracy: 73.216%
# >Saved:  g_model_0100.h5 and c_model_0100.h5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >101, c(loss and accuracy)[0.917,73], d(loss on real and fake)[1.628,1.639], d(acc on real and fake)[41.751,41.545], g(loss)[0.111]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >102, c(loss and accuracy)[0.918,73], d(loss on real and fake)[1.634,1.645], d(acc on real and fake)[41.724,41.520], g(loss)[0.110]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >103, c(loss and accuracy)[0.918,73], d(loss on real and fake)[1.640,1.651], d(acc on real and fake)[41.746,41.544], g(loss)[0.109]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >104, c(loss and accuracy)[0.919,73], d(loss on real and fake)[1.646,1.657], d(acc on real and fake)[41.729,41.529], g(loss)[0.108]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >105, c(loss and accuracy)[0.919,72], d(loss on real and fake)[1.651,1.662], d(acc on real and fake)[41.732,41.533], g(loss)[0.107]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >106, c(loss and accuracy)[0.919,72], d(loss on real and fake)[1.657,1.667], d(acc on real and fake)[41.716,41.519], g(loss)[0.107]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# >107, c(loss and accuracy)[0.920,72], d(loss on real and fake)[1.662,1.673], d(acc on real and fake)[41.723,41.528], g(loss)[0.106]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >108, c(loss and accuracy)[0.920,72], d(loss on real and fake)[1.667,1.678], d(acc on real and fake)[41.712,41.519], g(loss)[0.105]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >109, c(loss and accuracy)[0.920,72], d(loss on real and fake)[1.673,1.683], d(acc on real and fake)[41.714,41.523], g(loss)[0.104]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >110, c(loss and accuracy)[0.921,72], d(loss on real and fake)[1.678,1.689], d(acc on real and fake)[41.726,41.536], g(loss)[0.103]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >111, c(loss and accuracy)[0.921,71], d(loss on real and fake)[1.683,1.694], d(acc on real and fake)[41.747,41.559], g(loss)[0.103]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >112, c(loss and accuracy)[0.921,71], d(loss on real and fake)[1.688,1.698], d(acc on real and fake)[41.758,41.571], g(loss)[0.102]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >113, c(loss and accuracy)[0.922,71], d(loss on real and fake)[1.693,1.704], d(acc on real and fake)[41.724,41.540], g(loss)[0.101]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >114, c(loss and accuracy)[0.922,71], d(loss on real and fake)[1.698,1.709], d(acc on real and fake)[41.744,41.561], g(loss)[0.101]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >115, c(loss and accuracy)[0.922,71], d(loss on real and fake)[1.704,1.714], d(acc on real and fake)[41.734,41.552], g(loss)[0.100]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >116, c(loss and accuracy)[0.923,71], d(loss on real and fake)[1.709,1.719], d(acc on real and fake)[41.732,41.552], g(loss)[0.099]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >117, c(loss and accuracy)[0.923,71], d(loss on real and fake)[1.714,1.724], d(acc on real and fake)[41.730,41.551], g(loss)[0.098]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >118, c(loss and accuracy)[0.923,70], d(loss on real and fake)[1.719,1.729], d(acc on real and fake)[41.723,41.547], g(loss)[0.098]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >119, c(loss and accuracy)[0.924,70], d(loss on real and fake)[1.724,1.734], d(acc on real and fake)[41.751,41.576], g(loss)[0.097]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >120, c(loss and accuracy)[0.924,70], d(loss on real and fake)[1.729,1.739], d(acc on real and fake)[41.762,41.587], g(loss)[0.096]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >121, c(loss and accuracy)[0.924,70], d(loss on real and fake)[1.734,1.744], d(acc on real and fake)[41.743,41.570], g(loss)[0.096]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >122, c(loss and accuracy)[0.925,70], d(loss on real and fake)[1.739,1.748], d(acc on real and fake)[41.757,41.586], g(loss)[0.095]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >123, c(loss and accuracy)[0.925,70], d(loss on real and fake)[1.743,1.753], d(acc on real and fake)[41.731,41.561], g(loss)[0.095]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >124, c(loss and accuracy)[0.925,70], d(loss on real and fake)[1.748,1.757], d(acc on real and fake)[41.749,41.581], g(loss)[0.094]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >125, c(loss and accuracy)[0.926,69], d(loss on real and fake)[1.752,1.762], d(acc on real and fake)[41.751,41.584], g(loss)[0.093]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >126, c(loss and accuracy)[0.926,69], d(loss on real and fake)[1.757,1.766], d(acc on real and fake)[41.757,41.591], g(loss)[0.093]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >127, c(loss and accuracy)[0.926,69], d(loss on real and fake)[1.761,1.771], d(acc on real and fake)[41.763,41.598], g(loss)[0.092]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >128, c(loss and accuracy)[0.927,69], d(loss on real and fake)[1.766,1.775], d(acc on real and fake)[41.769,41.605], g(loss)[0.092]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >129, c(loss and accuracy)[0.927,69], d(loss on real and fake)[1.770,1.780], d(acc on real and fake)[41.767,41.605], g(loss)[0.091]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >130, c(loss and accuracy)[0.927,69], d(loss on real and fake)[1.775,1.784], d(acc on real and fake)[41.772,41.612], g(loss)[0.090]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >131, c(loss and accuracy)[0.928,69], d(loss on real and fake)[1.780,1.789], d(acc on real and fake)[41.766,41.607], g(loss)[0.090]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >132, c(loss and accuracy)[0.928,68], d(loss on real and fake)[1.784,1.794], d(acc on real and fake)[41.749,41.591], g(loss)[0.089]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >133, c(loss and accuracy)[0.928,68], d(loss on real and fake)[1.789,1.798], d(acc on real and fake)[41.762,41.605], g(loss)[0.089]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >134, c(loss and accuracy)[0.928,68], d(loss on real and fake)[1.793,1.802], d(acc on real and fake)[41.757,41.601], g(loss)[0.088]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >135, c(loss and accuracy)[0.929,68], d(loss on real and fake)[1.797,1.806], d(acc on real and fake)[41.736,41.581], g(loss)[0.088]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >136, c(loss and accuracy)[0.929,68], d(loss on real and fake)[1.801,1.810], d(acc on real and fake)[41.756,41.603], g(loss)[0.087]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >137, c(loss and accuracy)[0.929,68], d(loss on real and fake)[1.806,1.815], d(acc on real and fake)[41.758,41.606], g(loss)[0.087]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >138, c(loss and accuracy)[0.930,68], d(loss on real and fake)[1.810,1.819], d(acc on real and fake)[41.742,41.591], g(loss)[0.086]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >139, c(loss and accuracy)[0.930,68], d(loss on real and fake)[1.814,1.823], d(acc on real and fake)[41.744,41.594], g(loss)[0.086]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >140, c(loss and accuracy)[0.930,67], d(loss on real and fake)[1.818,1.827], d(acc on real and fake)[41.713,41.564], g(loss)[0.085]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >141, c(loss and accuracy)[0.930,67], d(loss on real and fake)[1.822,1.831], d(acc on real and fake)[41.722,41.574], g(loss)[0.085]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >142, c(loss and accuracy)[0.931,67], d(loss on real and fake)[1.826,1.835], d(acc on real and fake)[41.731,41.585], g(loss)[0.084]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >143, c(loss and accuracy)[0.931,67], d(loss on real and fake)[1.831,1.839], d(acc on real and fake)[41.740,41.594], g(loss)[0.084]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >144, c(loss and accuracy)[0.931,67], d(loss on real and fake)[1.835,1.843], d(acc on real and fake)[41.746,41.601], g(loss)[0.083]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >145, c(loss and accuracy)[0.932,67], d(loss on real and fake)[1.838,1.847], d(acc on real and fake)[41.751,41.607], g(loss)[0.083]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >146, c(loss and accuracy)[0.932,67], d(loss on real and fake)[1.842,1.851], d(acc on real and fake)[41.766,41.623], g(loss)[0.082]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >147, c(loss and accuracy)[0.932,67], d(loss on real and fake)[1.846,1.855], d(acc on real and fake)[41.754,41.612], g(loss)[0.082]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >148, c(loss and accuracy)[0.933,67], d(loss on real and fake)[1.850,1.858], d(acc on real and fake)[41.769,41.628], g(loss)[0.081]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >149, c(loss and accuracy)[0.933,66], d(loss on real and fake)[1.854,1.862], d(acc on real and fake)[41.768,41.628], g(loss)[0.081]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >150, c(loss and accuracy)[0.933,66], d(loss on real and fake)[1.858,1.866], d(acc on real and fake)[41.779,41.640], g(loss)[0.080]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >151, c(loss and accuracy)[0.933,66], d(loss on real and fake)[1.862,1.870], d(acc on real and fake)[41.791,41.652], g(loss)[0.080]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >152, c(loss and accuracy)[0.934,66], d(loss on real and fake)[1.865,1.873], d(acc on real and fake)[41.782,41.645], g(loss)[0.080]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >153, c(loss and accuracy)[0.934,66], d(loss on real and fake)[1.869,1.877], d(acc on real and fake)[41.774,41.637], g(loss)[0.079]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >154, c(loss and accuracy)[0.934,66], d(loss on real and fake)[1.873,1.881], d(acc on real and fake)[41.779,41.643], g(loss)[0.079]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >155, c(loss and accuracy)[0.934,66], d(loss on real and fake)[1.877,1.884], d(acc on real and fake)[41.783,41.648], g(loss)[0.078]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >156, c(loss and accuracy)[0.935,66], d(loss on real and fake)[1.880,1.888], d(acc on real and fake)[41.807,41.673], g(loss)[0.078]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >157, c(loss and accuracy)[0.935,66], d(loss on real and fake)[1.883,1.891], d(acc on real and fake)[41.786,41.653], g(loss)[0.077]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >158, c(loss and accuracy)[0.935,65], d(loss on real and fake)[1.887,1.895], d(acc on real and fake)[41.794,41.661], g(loss)[0.077]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >159, c(loss and accuracy)[0.936,65], d(loss on real and fake)[1.891,1.899], d(acc on real and fake)[41.789,41.657], g(loss)[0.077]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >160, c(loss and accuracy)[0.936,65], d(loss on real and fake)[1.895,1.902], d(acc on real and fake)[41.793,41.662], g(loss)[0.076]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >161, c(loss and accuracy)[0.936,65], d(loss on real and fake)[1.898,1.906], d(acc on real and fake)[41.760,41.630], g(loss)[0.076]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >162, c(loss and accuracy)[0.937,65], d(loss on real and fake)[1.902,1.909], d(acc on real and fake)[41.759,41.630], g(loss)[0.075]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >163, c(loss and accuracy)[0.937,65], d(loss on real and fake)[1.905,1.913], d(acc on real and fake)[41.772,41.644], g(loss)[0.075]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >164, c(loss and accuracy)[0.937,65], d(loss on real and fake)[1.909,1.917], d(acc on real and fake)[41.777,41.649], g(loss)[0.075]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >165, c(loss and accuracy)[0.938,65], d(loss on real and fake)[1.913,1.920], d(acc on real and fake)[41.766,41.639], g(loss)[0.074]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >166, c(loss and accuracy)[0.938,65], d(loss on real and fake)[1.916,1.924], d(acc on real and fake)[41.761,41.636], g(loss)[0.074]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >167, c(loss and accuracy)[0.938,65], d(loss on real and fake)[1.920,1.927], d(acc on real and fake)[41.772,41.647], g(loss)[0.074]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >168, c(loss and accuracy)[0.938,64], d(loss on real and fake)[1.923,1.930], d(acc on real and fake)[41.764,41.640], g(loss)[0.073]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >169, c(loss and accuracy)[0.939,64], d(loss on real and fake)[1.926,1.934], d(acc on real and fake)[41.766,41.642], g(loss)[0.073]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >170, c(loss and accuracy)[0.939,64], d(loss on real and fake)[1.929,1.937], d(acc on real and fake)[41.749,41.626], g(loss)[0.072]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >171, c(loss and accuracy)[0.939,64], d(loss on real and fake)[1.933,1.941], d(acc on real and fake)[41.745,41.623], g(loss)[0.072]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >172, c(loss and accuracy)[0.940,64], d(loss on real and fake)[1.936,1.944], d(acc on real and fake)[41.735,41.613], g(loss)[0.072]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >173, c(loss and accuracy)[0.940,64], d(loss on real and fake)[1.940,1.947], d(acc on real and fake)[41.725,41.604], g(loss)[0.071]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >174, c(loss and accuracy)[0.940,64], d(loss on real and fake)[1.943,1.950], d(acc on real and fake)[41.723,41.603], g(loss)[0.071]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >175, c(loss and accuracy)[0.941,64], d(loss on real and fake)[1.946,1.953], d(acc on real and fake)[41.734,41.614], g(loss)[0.071]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >176, c(loss and accuracy)[0.941,64], d(loss on real and fake)[1.949,1.957], d(acc on real and fake)[41.732,41.614], g(loss)[0.070]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >177, c(loss and accuracy)[0.941,64], d(loss on real and fake)[1.952,1.960], d(acc on real and fake)[41.745,41.627], g(loss)[0.070]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >178, c(loss and accuracy)[0.941,63], d(loss on real and fake)[1.956,1.963], d(acc on real and fake)[41.758,41.640], g(loss)[0.070]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >179, c(loss and accuracy)[0.942,63], d(loss on real and fake)[1.959,1.967], d(acc on real and fake)[41.748,41.631], g(loss)[0.069]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >180, c(loss and accuracy)[0.942,63], d(loss on real and fake)[1.963,1.970], d(acc on real and fake)[41.749,41.633], g(loss)[0.069]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >181, c(loss and accuracy)[0.942,63], d(loss on real and fake)[1.966,1.973], d(acc on real and fake)[41.737,41.622], g(loss)[0.069]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >182, c(loss and accuracy)[0.942,63], d(loss on real and fake)[1.969,1.976], d(acc on real and fake)[41.741,41.626], g(loss)[0.068]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >183, c(loss and accuracy)[0.943,63], d(loss on real and fake)[1.972,1.980], d(acc on real and fake)[41.745,41.631], g(loss)[0.068]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >184, c(loss and accuracy)[0.943,63], d(loss on real and fake)[1.976,1.983], d(acc on real and fake)[41.747,41.633], g(loss)[0.068]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >185, c(loss and accuracy)[0.943,63], d(loss on real and fake)[1.979,1.986], d(acc on real and fake)[41.759,41.646], g(loss)[0.068]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >186, c(loss and accuracy)[0.944,63], d(loss on real and fake)[1.982,1.989], d(acc on real and fake)[41.744,41.632], g(loss)[0.067]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >187, c(loss and accuracy)[0.944,63], d(loss on real and fake)[1.986,1.993], d(acc on real and fake)[41.740,41.628], g(loss)[0.067]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >188, c(loss and accuracy)[0.944,63], d(loss on real and fake)[1.989,1.996], d(acc on real and fake)[41.736,41.625], g(loss)[0.067]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >189, c(loss and accuracy)[0.944,62], d(loss on real and fake)[1.992,1.999], d(acc on real and fake)[41.729,41.619], g(loss)[0.066]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >190, c(loss and accuracy)[0.945,62], d(loss on real and fake)[1.995,2.002], d(acc on real and fake)[41.723,41.613], g(loss)[0.066]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >191, c(loss and accuracy)[0.945,62], d(loss on real and fake)[1.998,2.005], d(acc on real and fake)[41.719,41.610], g(loss)[0.066]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >192, c(loss and accuracy)[0.945,62], d(loss on real and fake)[2.001,2.008], d(acc on real and fake)[41.715,41.607], g(loss)[0.066]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >193, c(loss and accuracy)[0.945,62], d(loss on real and fake)[2.004,2.011], d(acc on real and fake)[41.714,41.606], g(loss)[0.065]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >194, c(loss and accuracy)[0.946,62], d(loss on real and fake)[2.007,2.014], d(acc on real and fake)[41.713,41.606], g(loss)[0.065]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >195, c(loss and accuracy)[0.946,62], d(loss on real and fake)[2.010,2.017], d(acc on real and fake)[41.730,41.623], g(loss)[0.065]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >196, c(loss and accuracy)[0.946,62], d(loss on real and fake)[2.013,2.020], d(acc on real and fake)[41.726,41.620], g(loss)[0.064]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >197, c(loss and accuracy)[0.946,62], d(loss on real and fake)[2.016,2.023], d(acc on real and fake)[41.720,41.614], g(loss)[0.064]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >198, c(loss and accuracy)[0.947,62], d(loss on real and fake)[2.019,2.026], d(acc on real and fake)[41.706,41.601], g(loss)[0.064]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >199, c(loss and accuracy)[0.947,62], d(loss on real and fake)[2.022,2.028], d(acc on real and fake)[41.708,41.603], g(loss)[0.064]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >200, c(loss and accuracy)[0.947,62], d(loss on real and fake)[2.025,2.032], d(acc on real and fake)[41.707,41.603], g(loss)[0.063]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Classifier Accuracy: 73.216%
# >Saved:  g_model_0200.h5 and c_model_0200.h5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >201, c(loss and accuracy)[0.917,73], d(loss on real and fake)[2.028,2.034], d(acc on real and fake)[41.716,41.612], g(loss)[0.063]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >202, c(loss and accuracy)[0.918,73], d(loss on real and fake)[2.031,2.037], d(acc on real and fake)[41.702,41.599], g(loss)[0.063]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >203, c(loss and accuracy)[0.918,73], d(loss on real and fake)[2.034,2.040], d(acc on real and fake)[41.696,41.594], g(loss)[0.063]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >204, c(loss and accuracy)[0.918,73], d(loss on real and fake)[2.037,2.043], d(acc on real and fake)[41.717,41.615], g(loss)[0.062]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >205, c(loss and accuracy)[0.919,72], d(loss on real and fake)[2.039,2.046], d(acc on real and fake)[41.714,41.612], g(loss)[0.062]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >206, c(loss and accuracy)[0.919,72], d(loss on real and fake)[2.042,2.049], d(acc on real and fake)[41.723,41.621], g(loss)[0.062]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >207, c(loss and accuracy)[0.919,72], d(loss on real and fake)[2.045,2.051], d(acc on real and fake)[41.717,41.616], g(loss)[0.061]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >208, c(loss and accuracy)[0.920,72], d(loss on real and fake)[2.048,2.054], d(acc on real and fake)[41.711,41.611], g(loss)[0.061]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >209, c(loss and accuracy)[0.920,72], d(loss on real and fake)[2.050,2.057], d(acc on real and fake)[41.712,41.612], g(loss)[0.061]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >210, c(loss and accuracy)[0.921,72], d(loss on real and fake)[2.053,2.060], d(acc on real and fake)[41.718,41.619], g(loss)[0.061]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >211, c(loss and accuracy)[0.921,71], d(loss on real and fake)[2.056,2.063], d(acc on real and fake)[41.710,41.611], g(loss)[0.061]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >212, c(loss and accuracy)[0.921,71], d(loss on real and fake)[2.059,2.065], d(acc on real and fake)[41.697,41.599], g(loss)[0.060]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >213, c(loss and accuracy)[0.922,71], d(loss on real and fake)[2.062,2.068], d(acc on real and fake)[41.689,41.592], g(loss)[0.060]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >214, c(loss and accuracy)[0.922,71], d(loss on real and fake)[2.065,2.071], d(acc on real and fake)[41.700,41.603], g(loss)[0.060]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >215, c(loss and accuracy)[0.922,71], d(loss on real and fake)[2.067,2.073], d(acc on real and fake)[41.711,41.614], g(loss)[0.060]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >216, c(loss and accuracy)[0.923,71], d(loss on real and fake)[2.070,2.076], d(acc on real and fake)[41.710,41.613], g(loss)[0.059]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >217, c(loss and accuracy)[0.923,71], d(loss on real and fake)[2.073,2.079], d(acc on real and fake)[41.697,41.601], g(loss)[0.059]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >218, c(loss and accuracy)[0.923,70], d(loss on real and fake)[2.075,2.081], d(acc on real and fake)[41.701,41.606], g(loss)[0.059]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >219, c(loss and accuracy)[0.924,70], d(loss on real and fake)[2.078,2.084], d(acc on real and fake)[41.698,41.603], g(loss)[0.059]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >220, c(loss and accuracy)[0.924,70], d(loss on real and fake)[2.081,2.087], d(acc on real and fake)[41.695,41.600], g(loss)[0.058]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >221, c(loss and accuracy)[0.924,70], d(loss on real and fake)[2.083,2.090], d(acc on real and fake)[41.692,41.597], g(loss)[0.058]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >222, c(loss and accuracy)[0.925,70], d(loss on real and fake)[2.086,2.092], d(acc on real and fake)[41.693,41.599], g(loss)[0.058]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >223, c(loss and accuracy)[0.925,70], d(loss on real and fake)[2.088,2.095], d(acc on real and fake)[41.701,41.608], g(loss)[0.058]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >224, c(loss and accuracy)[0.925,70], d(loss on real and fake)[2.091,2.097], d(acc on real and fake)[41.694,41.600], g(loss)[0.058]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >225, c(loss and accuracy)[0.925,70], d(loss on real and fake)[2.094,2.100], d(acc on real and fake)[41.684,41.591], g(loss)[0.057]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >226, c(loss and accuracy)[0.926,69], d(loss on real and fake)[2.096,2.102], d(acc on real and fake)[41.685,41.593], g(loss)[0.057]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >227, c(loss and accuracy)[0.926,69], d(loss on real and fake)[2.099,2.105], d(acc on real and fake)[41.689,41.597], g(loss)[0.057]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >228, c(loss and accuracy)[0.926,69], d(loss on real and fake)[2.101,2.107], d(acc on real and fake)[41.692,41.601], g(loss)[0.057]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >229, c(loss and accuracy)[0.927,69], d(loss on real and fake)[2.104,2.110], d(acc on real and fake)[41.691,41.600], g(loss)[0.056]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >230, c(loss and accuracy)[0.927,69], d(loss on real and fake)[2.106,2.113], d(acc on real and fake)[41.697,41.607], g(loss)[0.056]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >231, c(loss and accuracy)[0.927,69], d(loss on real and fake)[2.109,2.115], d(acc on real and fake)[41.701,41.610], g(loss)[0.056]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >232, c(loss and accuracy)[0.928,69], d(loss on real and fake)[2.111,2.117], d(acc on real and fake)[41.698,41.608], g(loss)[0.056]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >233, c(loss and accuracy)[0.928,68], d(loss on real and fake)[2.114,2.120], d(acc on real and fake)[41.699,41.609], g(loss)[0.056]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >234, c(loss and accuracy)[0.928,68], d(loss on real and fake)[2.116,2.122], d(acc on real and fake)[41.715,41.626], g(loss)[0.055]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >235, c(loss and accuracy)[0.929,68], d(loss on real and fake)[2.119,2.125], d(acc on real and fake)[41.714,41.626], g(loss)[0.055]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >236, c(loss and accuracy)[0.929,68], d(loss on real and fake)[2.121,2.127], d(acc on real and fake)[41.709,41.621], g(loss)[0.055]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >237, c(loss and accuracy)[0.929,68], d(loss on real and fake)[2.124,2.130], d(acc on real and fake)[41.706,41.618], g(loss)[0.055]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >238, c(loss and accuracy)[0.930,68], d(loss on real and fake)[2.126,2.132], d(acc on real and fake)[41.693,41.605], g(loss)[0.055]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >239, c(loss and accuracy)[0.930,68], d(loss on real and fake)[2.129,2.135], d(acc on real and fake)[41.696,41.609], g(loss)[0.054]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >240, c(loss and accuracy)[0.930,68], d(loss on real and fake)[2.131,2.137], d(acc on real and fake)[41.693,41.606], g(loss)[0.054]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >241, c(loss and accuracy)[0.931,67], d(loss on real and fake)[2.134,2.139], d(acc on real and fake)[41.701,41.614], g(loss)[0.054]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >242, c(loss and accuracy)[0.931,67], d(loss on real and fake)[2.136,2.142], d(acc on real and fake)[41.700,41.614], g(loss)[0.054]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >243, c(loss and accuracy)[0.931,67], d(loss on real and fake)[2.139,2.144], d(acc on real and fake)[41.705,41.619], g(loss)[0.054]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >244, c(loss and accuracy)[0.932,67], d(loss on real and fake)[2.141,2.147], d(acc on real and fake)[41.706,41.621], g(loss)[0.054]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >245, c(loss and accuracy)[0.932,67], d(loss on real and fake)[2.143,2.149], d(acc on real and fake)[41.685,41.600], g(loss)[0.053]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >246, c(loss and accuracy)[0.932,67], d(loss on real and fake)[2.146,2.152], d(acc on real and fake)[41.682,41.598], g(loss)[0.053]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >247, c(loss and accuracy)[0.933,67], d(loss on real and fake)[2.148,2.154], d(acc on real and fake)[41.688,41.603], g(loss)[0.053]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >248, c(loss and accuracy)[0.933,67], d(loss on real and fake)[2.151,2.156], d(acc on real and fake)[41.691,41.607], g(loss)[0.053]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >249, c(loss and accuracy)[0.933,66], d(loss on real and fake)[2.153,2.159], d(acc on real and fake)[41.696,41.612], g(loss)[0.053]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >250, c(loss and accuracy)[0.933,66], d(loss on real and fake)[2.155,2.161], d(acc on real and fake)[41.687,41.604], g(loss)[0.052]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >251, c(loss and accuracy)[0.934,66], d(loss on real and fake)[2.158,2.164], d(acc on real and fake)[41.689,41.606], g(loss)[0.052]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >252, c(loss and accuracy)[0.934,66], d(loss on real and fake)[2.160,2.166], d(acc on real and fake)[41.702,41.619], g(loss)[0.052]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >253, c(loss and accuracy)[0.934,66], d(loss on real and fake)[2.163,2.168], d(acc on real and fake)[41.701,41.619], g(loss)[0.052]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >254, c(loss and accuracy)[0.935,66], d(loss on real and fake)[2.165,2.171], d(acc on real and fake)[41.706,41.624], g(loss)[0.052]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >255, c(loss and accuracy)[0.935,66], d(loss on real and fake)[2.167,2.173], d(acc on real and fake)[41.707,41.625], g(loss)[0.052]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >256, c(loss and accuracy)[0.935,66], d(loss on real and fake)[2.170,2.175], d(acc on real and fake)[41.708,41.627], g(loss)[0.051]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >257, c(loss and accuracy)[0.936,66], d(loss on real and fake)[2.172,2.177], d(acc on real and fake)[41.702,41.621], g(loss)[0.051]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >258, c(loss and accuracy)[0.936,65], d(loss on real and fake)[2.174,2.180], d(acc on real and fake)[41.695,41.614], g(loss)[0.051]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >259, c(loss and accuracy)[0.936,65], d(loss on real and fake)[2.176,2.182], d(acc on real and fake)[41.683,41.602], g(loss)[0.051]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >260, c(loss and accuracy)[0.936,65], d(loss on real and fake)[2.179,2.184], d(acc on real and fake)[41.684,41.604], g(loss)[0.051]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >261, c(loss and accuracy)[0.937,65], d(loss on real and fake)[2.181,2.186], d(acc on real and fake)[41.679,41.600], g(loss)[0.051]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >262, c(loss and accuracy)[0.937,65], d(loss on real and fake)[2.183,2.189], d(acc on real and fake)[41.663,41.584], g(loss)[0.050]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >263, c(loss and accuracy)[0.937,65], d(loss on real and fake)[2.185,2.191], d(acc on real and fake)[41.665,41.586], g(loss)[0.050]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >264, c(loss and accuracy)[0.937,65], d(loss on real and fake)[2.188,2.193], d(acc on real and fake)[41.666,41.587], g(loss)[0.050]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >265, c(loss and accuracy)[0.938,65], d(loss on real and fake)[2.190,2.195], d(acc on real and fake)[41.658,41.579], g(loss)[0.050]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >266, c(loss and accuracy)[0.938,65], d(loss on real and fake)[2.192,2.197], d(acc on real and fake)[41.667,41.588], g(loss)[0.050]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >267, c(loss and accuracy)[0.938,65], d(loss on real and fake)[2.194,2.199], d(acc on real and fake)[41.668,41.590], g(loss)[0.050]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >268, c(loss and accuracy)[0.939,64], d(loss on real and fake)[2.196,2.202], d(acc on real and fake)[41.667,41.590], g(loss)[0.049]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >269, c(loss and accuracy)[0.939,64], d(loss on real and fake)[2.198,2.204], d(acc on real and fake)[41.678,41.600], g(loss)[0.049]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >270, c(loss and accuracy)[0.939,64], d(loss on real and fake)[2.201,2.206], d(acc on real and fake)[41.668,41.591], g(loss)[0.049]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >271, c(loss and accuracy)[0.940,64], d(loss on real and fake)[2.203,2.208], d(acc on real and fake)[41.669,41.592], g(loss)[0.049]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >272, c(loss and accuracy)[0.940,64], d(loss on real and fake)[2.205,2.210], d(acc on real and fake)[41.685,41.608], g(loss)[0.049]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >273, c(loss and accuracy)[0.940,64], d(loss on real and fake)[2.207,2.212], d(acc on real and fake)[41.681,41.604], g(loss)[0.049]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >274, c(loss and accuracy)[0.940,64], d(loss on real and fake)[2.209,2.214], d(acc on real and fake)[41.678,41.602], g(loss)[0.048]
# ...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >399, c(loss and accuracy)[0.919,57], d(loss on real and fake)[1.790,1.792], d(acc on real and fake)[25.064,25.033], g(loss)[0.090]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >400, c(loss and accuracy)[0.919,56], d(loss on real and fake)[1.791,1.793], d(acc on real and fake)[25.065,25.034], g(loss)[0.090]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Classifier Accuracy: 66.049%
# >Saved:  g_model_0400.h5 and c_model_0400.h5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >401, c(loss and accuracy)[0.839,66], d(loss on real and fake)[1.791,1.794], d(acc on real and fake)[25.065,25.034], g(loss)[0.090]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >402, c(loss and accuracy)[0.840,66], d(loss on real and fake)[1.792,1.795], d(acc on real and fake)[25.066,25.035], g(loss)[0.090]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >403, c(loss and accuracy)[0.841,66], d(loss on real and fake)[1.793,1.795], d(acc on real and fake)[25.070,25.038], g(loss)[0.089]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >404, c(loss and accuracy)[0.841,66], d(loss on real and fake)[1.794,1.796], d(acc on real and fake)[25.067,25.036], g(loss)[0.089]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >405, c(loss and accuracy)[0.842,65], d(loss on real and fake)[1.795,1.797], d(acc on real and fake)[25.069,25.038], g(loss)[0.089]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >406, c(loss and accuracy)[0.843,65], d(loss on real and fake)[1.796,1.798], d(acc on real and fake)[25.079,25.048], g(loss)[0.089]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >407, c(loss and accuracy)[0.844,65], d(loss on real and fake)[1.797,1.799], d(acc on real and fake)[25.076,25.045], g(loss)[0.089]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >408, c(loss and accuracy)[0.845,65], d(loss on real and fake)[1.798,1.800], d(acc on real and fake)[25.079,25.048], g(loss)[0.089]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >409, c(loss and accuracy)[0.845,65], d(loss on real and fake)[1.799,1.801], d(acc on real and fake)[25.075,25.044], g(loss)[0.089]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >410, c(loss and accuracy)[0.846,65], d(loss on real and fake)[1.799,1.802], d(acc on real and fake)[25.076,25.045], g(loss)[0.088]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >411, c(loss and accuracy)[0.847,65], d(loss on real and fake)[1.800,1.803], d(acc on real and fake)[25.078,25.047], g(loss)[0.088]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >412, c(loss and accuracy)[0.848,65], d(loss on real and fake)[1.801,1.803], d(acc on real and fake)[25.083,25.052], g(loss)[0.088]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >413, c(loss and accuracy)[0.849,64], d(loss on real and fake)[1.802,1.804], d(acc on real and fake)[25.080,25.050], g(loss)[0.088]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >414, c(loss and accuracy)[0.850,64], d(loss on real and fake)[1.803,1.805], d(acc on real and fake)[25.081,25.051], g(loss)[0.088]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >415, c(loss and accuracy)[0.851,64], d(loss on real and fake)[1.804,1.806], d(acc on real and fake)[25.082,25.052], g(loss)[0.088]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >416, c(loss and accuracy)[0.852,64], d(loss on real and fake)[1.804,1.807], d(acc on real and fake)[25.088,25.058], g(loss)[0.087]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >417, c(loss and accuracy)[0.853,64], d(loss on real and fake)[1.805,1.808], d(acc on real and fake)[25.092,25.062], g(loss)[0.087]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >418, c(loss and accuracy)[0.853,64], d(loss on real and fake)[1.806,1.808], d(acc on real and fake)[25.086,25.056], g(loss)[0.087]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >419, c(loss and accuracy)[0.854,64], d(loss on real and fake)[1.807,1.809], d(acc on real and fake)[25.078,25.048], g(loss)[0.087]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >420, c(loss and accuracy)[0.855,64], d(loss on real and fake)[1.808,1.810], d(acc on real and fake)[25.086,25.056], g(loss)[0.087]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >421, c(loss and accuracy)[0.856,64], d(loss on real and fake)[1.809,1.811], d(acc on real and fake)[25.087,25.057], g(loss)[0.087]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >422, c(loss and accuracy)[0.856,63], d(loss on real and fake)[1.810,1.812], d(acc on real and fake)[25.088,25.058], g(loss)[0.087]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >423, c(loss and accuracy)[0.858,63], d(loss on real and fake)[1.811,1.813], d(acc on real and fake)[25.077,25.047], g(loss)[0.087]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >424, c(loss and accuracy)[0.858,63], d(loss on real and fake)[1.811,1.814], d(acc on real and fake)[25.084,25.054], g(loss)[0.086]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >425, c(loss and accuracy)[0.859,63], d(loss on real and fake)[1.812,1.814], d(acc on real and fake)[25.078,25.048], g(loss)[0.086]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >426, c(loss and accuracy)[0.860,63], d(loss on real and fake)[1.813,1.815], d(acc on real and fake)[25.073,25.043], g(loss)[0.086]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >427, c(loss and accuracy)[0.861,63], d(loss on real and fake)[1.814,1.816], d(acc on real and fake)[25.062,25.033], g(loss)[0.086]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >428, c(loss and accuracy)[0.862,63], d(loss on real and fake)[1.815,1.817], d(acc on real and fake)[25.063,25.034], g(loss)[0.086]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >429, c(loss and accuracy)[0.863,63], d(loss on real and fake)[1.816,1.818], d(acc on real and fake)[25.071,25.042], g(loss)[0.086]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >430, c(loss and accuracy)[0.864,63], d(loss on real and fake)[1.817,1.819], d(acc on real and fake)[25.064,25.035], g(loss)[0.086]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >431, c(loss and accuracy)[0.864,62], d(loss on real and fake)[1.817,1.819], d(acc on real and fake)[25.071,25.042], g(loss)[0.085]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >432, c(loss and accuracy)[0.865,62], d(loss on real and fake)[1.818,1.820], d(acc on real and fake)[25.060,25.031], g(loss)[0.085]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >433, c(loss and accuracy)[0.866,62], d(loss on real and fake)[1.819,1.821], d(acc on real and fake)[25.058,25.029], g(loss)[0.085]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# >434, c(loss and accuracy)[0.867,62], d(loss on real and fake)[1.820,1.822], d(acc on real and fake)[25.059,25.030], g(loss)[0.085]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >435, c(loss and accuracy)[0.868,62], d(loss on real and fake)[1.821,1.823], d(acc on real and fake)[25.061,25.032], g(loss)[0.085]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >436, c(loss and accuracy)[0.869,62], d(loss on real and fake)[1.821,1.823], d(acc on real and fake)[25.056,25.028], g(loss)[0.085]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >437, c(loss and accuracy)[0.870,62], d(loss on real and fake)[1.822,1.824], d(acc on real and fake)[25.047,25.018], g(loss)[0.085]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >438, c(loss and accuracy)[0.870,62], d(loss on real and fake)[1.823,1.825], d(acc on real and fake)[25.049,25.021], g(loss)[0.084]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >439, c(loss and accuracy)[0.871,62], d(loss on real and fake)[1.824,1.826], d(acc on real and fake)[25.043,25.015], g(loss)[0.084]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >440, c(loss and accuracy)[0.872,62], d(loss on real and fake)[1.825,1.827], d(acc on real and fake)[25.046,25.017], g(loss)[0.084]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >441, c(loss and accuracy)[0.873,61], d(loss on real and fake)[1.826,1.828], d(acc on real and fake)[25.035,25.007], g(loss)[0.084]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >442, c(loss and accuracy)[0.874,61], d(loss on real and fake)[1.827,1.829], d(acc on real and fake)[25.028,25.000], g(loss)[0.084]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >443, c(loss and accuracy)[0.875,61], d(loss on real and fake)[1.827,1.829], d(acc on real and fake)[25.027,24.999], g(loss)[0.084]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >444, c(loss and accuracy)[0.876,61], d(loss on real and fake)[1.828,1.830], d(acc on real and fake)[25.016,24.988], g(loss)[0.084]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >445, c(loss and accuracy)[0.876,61], d(loss on real and fake)[1.829,1.831], d(acc on real and fake)[25.010,24.982], g(loss)[0.084]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >446, c(loss and accuracy)[0.877,61], d(loss on real and fake)[1.830,1.832], d(acc on real and fake)[25.011,24.983], g(loss)[0.083]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >447, c(loss and accuracy)[0.878,61], d(loss on real and fake)[1.830,1.832], d(acc on real and fake)[25.007,24.979], g(loss)[0.083]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >448, c(loss and accuracy)[0.879,61], d(loss on real and fake)[1.831,1.833], d(acc on real and fake)[25.019,24.991], g(loss)[0.083]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >449, c(loss and accuracy)[0.880,61], d(loss on real and fake)[1.832,1.834], d(acc on real and fake)[25.018,24.990], g(loss)[0.083]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >450, c(loss and accuracy)[0.880,61], d(loss on real and fake)[1.833,1.835], d(acc on real and fake)[25.011,24.983], g(loss)[0.083]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >451, c(loss and accuracy)[0.881,60], d(loss on real and fake)[1.833,1.836], d(acc on real and fake)[25.004,24.977], g(loss)[0.083]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >452, c(loss and accuracy)[0.882,60], d(loss on real and fake)[1.834,1.836], d(acc on real and fake)[25.006,24.978], g(loss)[0.083]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >453, c(loss and accuracy)[0.883,60], d(loss on real and fake)[1.835,1.837], d(acc on real and fake)[25.006,24.978], g(loss)[0.083]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >454, c(loss and accuracy)[0.884,60], d(loss on real and fake)[1.836,1.838], d(acc on real and fake)[25.013,24.986], g(loss)[0.082]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >455, c(loss and accuracy)[0.885,60], d(loss on real and fake)[1.837,1.839], d(acc on real and fake)[25.017,24.989], g(loss)[0.082]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >456, c(loss and accuracy)[0.885,60], d(loss on real and fake)[1.837,1.839], d(acc on real and fake)[25.008,24.980], g(loss)[0.082]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >457, c(loss and accuracy)[0.886,60], d(loss on real and fake)[1.838,1.840], d(acc on real and fake)[25.011,24.984], g(loss)[0.082]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >458, c(loss and accuracy)[0.887,60], d(loss on real and fake)[1.839,1.841], d(acc on real and fake)[25.010,24.983], g(loss)[0.082]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# >459, c(loss and accuracy)[0.888,60], d(loss on real and fake)[1.840,1.842], d(acc on real and fake)[25.010,24.983], g(loss)[0.082]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# >460, c(loss and accuracy)[0.888,60], d(loss on real and fake)[1.840,1.843], d(acc on real and fake)[25.012,24.985], g(loss)[0.082]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# >461, c(loss and accuracy)[0.889,60], d(loss on real and fake)[1.841,1.843], d(acc on real and fake)[25.009,24.982], g(loss)[0.082]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# >462, c(loss and accuracy)[0.890,59], d(loss on real and fake)[1.842,1.844], d(acc on real and fake)[25.013,24.986], g(loss)[0.082]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >463, c(loss and accuracy)[0.891,59], d(loss on real and fake)[1.843,1.845], d(acc on real and fake)[25.015,24.988], g(loss)[0.081]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >464, c(loss and accuracy)[0.892,59], d(loss on real and fake)[1.843,1.845], d(acc on real and fake)[25.023,24.996], g(loss)[0.081]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >465, c(loss and accuracy)[0.892,59], d(loss on real and fake)[1.844,1.846], d(acc on real and fake)[25.022,24.995], g(loss)[0.081]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# >466, c(loss and accuracy)[0.893,59], d(loss on real and fake)[1.845,1.847], d(acc on real and fake)[25.019,24.992], g(loss)[0.081]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >467, c(loss and accuracy)[0.894,59], d(loss on real and fake)[1.846,1.848], d(acc on real and fake)[25.028,25.001], g(loss)[0.081]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >468, c(loss and accuracy)[0.895,59], d(loss on real and fake)[1.847,1.848], d(acc on real and fake)[25.018,24.991], g(loss)[0.081]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >469, c(loss and accuracy)[0.896,59], d(loss on real and fake)[1.847,1.849], d(acc on real and fake)[25.011,24.984], g(loss)[0.081]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >470, c(loss and accuracy)[0.896,59], d(loss on real and fake)[1.848,1.850], d(acc on real and fake)[25.006,24.980], g(loss)[0.081]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >471, c(loss and accuracy)[0.897,59], d(loss on real and fake)[1.849,1.851], d(acc on real and fake)[25.018,24.992], g(loss)[0.080]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >472, c(loss and accuracy)[0.898,59], d(loss on real and fake)[1.850,1.851], d(acc on real and fake)[25.012,24.985], g(loss)[0.080]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >473, c(loss and accuracy)[0.898,59], d(loss on real and fake)[1.850,1.852], d(acc on real and fake)[25.013,24.986], g(loss)[0.080]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >474, c(loss and accuracy)[0.899,58], d(loss on real and fake)[1.851,1.853], d(acc on real and fake)[25.010,24.983], g(loss)[0.080]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >475, c(loss and accuracy)[0.900,58], d(loss on real and fake)[1.852,1.854], d(acc on real and fake)[25.011,24.984], g(loss)[0.080]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >476, c(loss and accuracy)[0.901,58], d(loss on real and fake)[1.852,1.854], d(acc on real and fake)[25.011,24.984], g(loss)[0.080]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >477, c(loss and accuracy)[0.901,58], d(loss on real and fake)[1.853,1.855], d(acc on real and fake)[25.003,24.977], g(loss)[0.080]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >478, c(loss and accuracy)[0.902,58], d(loss on real and fake)[1.854,1.856], d(acc on real and fake)[25.002,24.976], g(loss)[0.080]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >479, c(loss and accuracy)[0.903,58], d(loss on real and fake)[1.855,1.857], d(acc on real and fake)[24.994,24.968], g(loss)[0.080]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >480, c(loss and accuracy)[0.904,58], d(loss on real and fake)[1.855,1.857], d(acc on real and fake)[24.996,24.970], g(loss)[0.079]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >481, c(loss and accuracy)[0.904,58], d(loss on real and fake)[1.856,1.858], d(acc on real and fake)[24.991,24.965], g(loss)[0.079]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >482, c(loss and accuracy)[0.905,58], d(loss on real and fake)[1.857,1.859], d(acc on real and fake)[24.993,24.967], g(loss)[0.079]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >483, c(loss and accuracy)[0.906,58], d(loss on real and fake)[1.857,1.859], d(acc on real and fake)[24.996,24.970], g(loss)[0.079]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >484, c(loss and accuracy)[0.906,58], d(loss on real and fake)[1.858,1.860], d(acc on real and fake)[25.000,24.974], g(loss)[0.079]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >485, c(loss and accuracy)[0.907,58], d(loss on real and fake)[1.859,1.861], d(acc on real and fake)[24.997,24.971], g(loss)[0.079]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >486, c(loss and accuracy)[0.908,58], d(loss on real and fake)[1.860,1.861], d(acc on real and fake)[24.996,24.970], g(loss)[0.079]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# >487, c(loss and accuracy)[0.909,57], d(loss on real and fake)[1.860,1.862], d(acc on real and fake)[25.003,24.977], g(loss)[0.079]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# >488, c(loss and accuracy)[0.909,57], d(loss on real and fake)[1.861,1.863], d(acc on real and fake)[25.011,24.986], g(loss)[0.079]

# %%
test_loss, test_accuracy = c_model.evaluate(X_test, y_test, verbose=0)
print('Test Accuracy for multiclass classification model: %.3f%%' % (test_accuracy * 100))
# Out:
# Test Accuracy for multiclass classification model: 73.607%
